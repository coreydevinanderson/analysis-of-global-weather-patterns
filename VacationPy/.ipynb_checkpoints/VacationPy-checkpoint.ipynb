# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import gmaps
import os

# %%
# Remove
gkey = ""
gmaps.configure(api_key = gkey)

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
# To read .csv back in...
weather_batch_all = pd.read_csv("..\WeatherPy\output_data\city_weather.csv", index_col = 0)
weather_batch_all.head(50)
# Out:
#                  city  latitude     longitude  max_temp  humidity  \
# 0           Kingisepp     58.92  2.854000e+01     32.90      93.0
# 1         Provideniya     53.36 -1.769900e+02     39.97      59.0
# 2          Negru voda     43.61  2.822000e+01     45.00      93.0
# 3             Paamiut     55.70 -5.055000e+01     32.11      77.0
# 4              Barrow     84.17 -1.438900e+02     28.40      69.0
# 5             Huaihua     27.51  1.097100e+02     65.62      96.0
# 6             Mumford      3.81 -1.637090e-10     81.00      85.0
# 7       Pacific grove     30.61 -1.313900e+02     57.00      86.0
# 8        Punta arenas    -69.78 -1.123600e+02     42.80      93.0
# 9              Visnes     57.99  2.050000e+00     41.00      70.0
# 10              Kieta      0.79  1.602800e+02     84.24      67.0
# 11              Tiksi     82.24  1.271000e+02     16.84      81.0
# 12            Rikitea    -28.88 -1.409900e+02     79.03      72.0
# 13          Cape town    -63.90 -1.100000e-01     59.00      82.0
# 14      Mar del plata    -46.49 -4.741000e+01     66.20      72.0
# 15              Prado    -17.73 -3.667000e+01     74.79      85.0
# 16            Mataura    -55.83 -1.498500e+02     50.00      84.0
# 17             Atuona      9.99 -1.301900e+02     80.38      78.0
# 18              Bluff    -67.99  1.714700e+02     50.00      84.0
# 19           La ligua    -32.28 -7.131000e+01     56.64      87.0
# 20             Dingle     50.43 -1.968000e+01     89.60      53.0
# 21          Lugovskoy     56.96  6.441000e+01     44.60      42.0
# 22               Lebu    -32.66 -1.001700e+02     52.45      91.0
# 23                Vao    -28.14  1.654500e+02     75.92      74.0
# 24         Butaritari     18.81  1.643600e+02     81.37      78.0
# 25              Ruiru     -1.15  3.700000e+01     64.40     100.0
# 26    Arraial do cabo    -26.64 -3.648000e+01     73.72      77.0
# 27         Talcahuano    -30.63 -8.368000e+01     55.40      94.0
# 28       Saint george     27.01 -5.623000e+01     78.80       9.0
# 29           Ratodero     27.79  6.824000e+01     73.40      60.0
# 30              Boiro     42.53 -8.990000e+00     59.00      94.0
# 31  Sao joao da barra    -28.32 -3.251000e+01     69.24      87.0
# 32               Hilo     15.19 -1.513300e+02     78.80      65.0
# 33           Khatanga     73.21  1.032700e+02     33.26      96.0
# 34             Bethel     48.97 -1.659800e+02     57.20      24.0
# 35            Klyuchi     55.38  1.609700e+02     38.57      62.0
# 36               Ayan     54.97  1.382400e+02     34.41      64.0
# 37         Westerland     54.76  8.580000e+00     41.00      85.0
# 38       Jacareacanga     -6.73 -5.877000e+01     74.37      97.0
# 39              Mugan     40.34  4.910000e+01     50.74      44.0
# 40            Ushuaia    -74.89 -5.256000e+01     42.80      93.0
# 41          Fairbanks     64.12 -1.462100e+02     57.99      21.0
# 42        East london    -87.38  5.959000e+01     62.29      75.0
# 43              Kapaa     15.36 -1.699300e+02     77.00      73.0
# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
# Access maps with unique API key
gmaps.configure(api_key = gkey)

# %%
# Store latitude and longitude in locations
locations = weather_batch_all[["latitude", "longitude"]]
humidity = weather_batch_all["humidity"]

# Customize the size of the figure
figure_layout = {
    'width': '800px',
    'height': '600px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}


# Plot Heatmap
fig = gmaps.figure(center = (0, 0), zoom_level = 1.65, layout = figure_layout)

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, 
                                 weights = humidity, 
                                 dissipating = True, 
                                 max_intensity = 200,
                                 point_radius = 40,
                                 opacity = 0.3)


# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='600px', margin='0 auto 0 auto', padding='1px', wi…

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
# Let's head to the rain forest! Hot and wet!

hot_and_wet = weather_batch_all.loc[(weather_batch_all["humidity"] > 80) &
                                    (weather_batch_all["wind_speed"] < 20.0) &
                                    (weather_batch_all["cloud_cover"] > 50) &
                                    (weather_batch_all["max_temp"] > 80.0)]

hot_and_wet.head()
# Out:
#          city  latitude     longitude  max_temp  humidity  cloud_cover  \
# 6     Mumford      3.81 -1.637090e-10     81.00      85.0        100.0
# 66     Harper     -4.06 -6.700000e+00     80.62      83.0         84.0
# 161     Tabou     -3.84 -5.030000e+00     80.02      84.0         94.0
# 211   Caucaia     -1.79 -3.714000e+01     82.00      89.0         75.0
# 352  Acapulco      5.59 -1.031500e+02     80.60      83.0         90.0
#
#      wind_speed country                 date
# 6          9.91      GH  2021-04-24 01:47:26
# 66         7.90      LR  2021-04-24 01:48:43
# 161        7.27      CI  2021-04-24 01:51:12
# 211        3.44      BR  2021-04-24 01:53:28
# 352        9.22      MX  2021-04-24 01:59:40

# %%
hotel_df = hot_and_wet.copy()
hotel_df.reset_index(drop = True, inplace = True)
hotel_df.head()
# Out:
#        city  latitude     longitude  max_temp  humidity  cloud_cover  \
# 0   Mumford      3.81 -1.637090e-10     81.00      85.0        100.0
# 1    Harper     -4.06 -6.700000e+00     80.62      83.0         84.0
# 2     Tabou     -3.84 -5.030000e+00     80.02      84.0         94.0
# 3   Caucaia     -1.79 -3.714000e+01     82.00      89.0         75.0
# 4  Acapulco      5.59 -1.031500e+02     80.60      83.0         90.0
#
#    wind_speed country                 date
# 0        9.91      GH  2021-04-24 01:47:26
# 1        7.90      LR  2021-04-24 01:48:43
# 2        7.27      CI  2021-04-24 01:51:12
# 3        3.44      BR  2021-04-24 01:53:28
# 4        9.22      MX  2021-04-24 01:59:40

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df.loc[0, "latitude"]
lat = weather_batch_all.loc[41, "latitude"]
lon = weather_batch_all.loc[41, "longitude"]
test_string = f"{round(lat, 5)}, {round(lon, 5)}"
print(test_string)
# Out:
# 64.12, -146.21

# %%
# geocoordinates
target_coordinates = test_string
target_radius = 50000
target_type = "lodging"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    "key": gkey
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)

# %%
# convert response to json
places_data = response.json()

# Print the json (pretty printed)
print(json.dumps(places_data, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "ATtYB

#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104670519566570939098\">Alaskan Steakhouse &amp; Motel</a>"
#                     ],
#                     "photo_reference": "ATtYBwK49hAiSISxURywRzlV2XyxHLQm-UjthJjp1mhfhi1tzrdB9NGb8CW1PaDhYmvQj_RdI6Thib6FO1ljBlKo2zaKXYUafnOwiJLKE4qNy_WitTfm2euJjcK7TcxtOrpPaVDbbTbmEAQMP_UN_g9bzPwz7U4nRKgqgYanWAHexfgIbn2Y",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJi2XRh8-LNFER9mOJOp5jQFk",
#             "plus_code": {
#                 "compound_code": "27J9+Q8 Delta Junction, AK, USA",
#                 "global_code": "93PP27J9+Q8"
#             },
#             "rating": 3.9,
#             "reference": "ChIJi2XRh8-LNFER9mOJOp5jQFk",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "bar",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 174,
#             "vicinity": "Mile, 265 Richardson Highway, Delta Junction"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 64.0413155,
#                     "lng": -145.7340523
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 64.04282593029151,
#                         "lng": -145.7329721697085
#                     },
#                     "southwest": {
#                         "lat": 64.04012796970851,
#                         "lng": -145.7356701302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Kelly's Alaska Country Inn",
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113830111160449561108\">Fronty Parker</a>"
#                     ],
#                     "photo_reference": "ATtYBwK5COT_enQNzAyWREfFt-LDhaVCpLM5aPMAgzN9VXCKofuoT1kGl0ik8k5i9vkHRPYAAYGM8oDFb1GJpsocAxzrsg1qt8Za-u5d2vH5Yo8jpCFCyArvikRMTxGAMIg3qCFwpM_a52CcGCoy3vWc9hxVE9tL41nJkxabvs3t0pShVTIe",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJT1KZicaLNFERnZx-ccHsuUs",
#             "plus_code": {
#                 "compound_code": "27R8+G9 Delta Junction, AK, USA",
#                 "global_code": "93PP27R8+G9"
#             },
#             "rating": 4.3,
#             "reference": "ChIJT1KZicaLNFERnZx-ccHsuUs",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 32,
#             "vicinity": "United States"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 64.0402146,
#                     "lng": -145.727443
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 64.04158873029151,
#                         "lng": -145.7258796697085
#                     },
#                     "southwest": {
#                         "lat": 64.03889076970849,
#                         "lng": -145.7285776302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Buffalo Rentals: The Bunk House",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2988,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105492107956780828776\">Buffalo Rentals: The Bunk House</a>"
#                     ],
#                     "photo_reference": "ATtYBwKcMYyODqsS_8IxTQX22Crf92rfu0hln1XRQZfiEuBR_cQW-FA6jnmTXwcMSnHXhfSTym1mfVcTe6UtGcS50Y2kM27iunflTP5g7g9ZgLVAA3kxO_OAHrIWZNvFBSiSiIUtBKMaimIsWe2MKN54AJYN3rEbuhDiB6yxyKEjiLD85QXW",
#                     "width": 5312
#                 }
#             ],
#             "place_id": "ChIJ27GJXPeLNFERxkb3qr0Qffk",
#             "plus_code": {
#                 "compound_code": "27RF+32 Delta Junction, AK, USA",
#                 "global_code": "93PP27RF+32"
#             },
#             "rating": 3.7,
#             "reference": "ChIJ27GJXPeLNFERxkb3qr0Qffk",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 7,
#             "vicinity": "1555 Richardson Avenue, Delta Junction"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 64.0344085,
#                     "lng": -145.7226715
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 64.03607008029151,
#                         "lng": -145.7204258
#                     },
#                     "southwest": {
#                         "lat": 64.03337211970849,
#                         "lng": -145.7250546
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Diamond Willow Inn",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 508,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108441800014295372073\">Diamond Willow Inn</a>"
#                     ],
#                     "photo_reference": "ATtYBwJzM8JvEXXJJ2YfqTT8HnEC_uINidKXUZOdHhPZSeP0ORTUKeJMuNPLHPUvETC1xUTu07d7nr3B54Q7nFyh-kdCA9LAbljUm1SX1tnVtkMlfAB0V3eVdo7WoVD3OEjIPbAoTYXazQw-BWDIuuc_DSCqF4arORvQmZRjwDag9sue-7nF",
#                     "width": 640
#                 }
#             ],
#             "place_id": "ChIJn0Gwo8eLNFERxDH_K2v7Qa0",
#             "plus_code": {
#                 "compound_code": "27MG+QW Delta Junction, AK, USA",
#                 "global_code": "93PP27MG+QW"
#             },
#             "rating": 4.5,
#             "reference": "ChIJn0Gwo8eLNFERxDH_K2v7Qa0",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 65,
#             "vicinity": "2485 Alaska Highway, Delta Junction"
#         },
#         {
#             "business_status": "CLOSED_TEMPORARILY",
#             "geometry": {
#                 "location": {
#                     "lat": 64.05175009999999,
#                     "lng": -145.4259948
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 64.0529056302915,
#                         "lng": -145.4251051197085
#                     },
#                     "southwest": {
#                         "lat": 64.0502076697085,
#                         "lng": -145.4278030802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Clearwater Lodge",
#             "permanently_closed": true,
#             "photos": [
#                 {
#                     "height": 2448,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108356288267470940210\">Clearwater Lodge</a>"
#                     ],
#                     "photo_reference": "ATtYBwIAU-SEnZqM4xFHV85xwWGwK_I2OzIFCpOuernAWSQn7mR_E0Mi_o3DDTBWd1iX4Mm07PV8a5sRBqUtCHHU1J78iLWIYR5wAF7jx7hY5IhUkTn1MLDXv7k_z76sAVptzbPB7oqonFjL9u9BQOspsky8EVJTAu4qe7G33Dx3IeMi2lQv",
#                     "width": 3264
#                 }
#             ],
#             "place_id": "ChIJD22Qb5ZfNFERNHRHQhGAqYA",
#             "plus_code": {
#                 "compound_code": "3H2F+PJ Delta Junction, AK, USA",
#                 "global_code": "93PP3H2F+PJ"
#             },
#             "rating": 4.5,
#             "reference": "ChIJD22Qb5ZfNFERNHRHQhGAqYA",
#             "scope": "GOOGLE",
#             "types": [
#                 "laundry",
#                 "rv_park",
#                 "lodging",
#                 "bar",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 154,
#             "vicinity": "7826 Remington Road, Delta Junction"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 64.0609528,
#                     "lng": -145.7356617
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 64.0621963302915,
#                         "lng": -145.7347857697085
#                     },
#                     "southwest": {
#                         "lat": 64.05949836970849,
#                         "lng": -145.7374837302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/camping-71.png",
#             "name": "Alaska Rv Ranch",
#             "photos": [
#                 {
#                     "height": 2336,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115995788753552765081\">Nicola Losego</a>"
#                     ],
#                     "photo_reference": "ATtYBwLYdVFiYp6UoF7ubG6Hlmdn6CHJUrW3UHN3wipjTeu4hmlQO5hFHb6UUgQ5QKpafcMyFrIdVGpZNIVQz5I-x5oYPh1qaQlFUKENZnblYUpsqhX9R0Jx5psEEPJZpT9kfVMNHIsXXHDB-_V74ODYjCO483_DrKUTAvcRlKVRu5rc5H3O",
#                     "width": 3504
#                 }
#             ],
#             "place_id": "ChIJ4waFJYeJNFERrTEC0foAoEI",
#             "plus_code": {
#                 "compound_code": "3767+9P Delta Junction, AK, USA",
#                 "global_code": "93PP3767+9P"
#             },
#             "rating": 4,
#             "reference": "ChIJ4waFJYeJNFERrTEC0foAoEI",
#             "scope": "GOOGLE",
#             "types": [
#                 "campground",
#                 "lodging",
#                 "park",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "2296 Richardson Highway, Delta Junction"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 64.1332707,
#                     "lng": -145.6841849
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 64.13520068029149,
#                         "lng": -145.6824032197085
#                     },
#                     "southwest": {
#                         "lat": 64.13250271970848,
#                         "lng": -145.6851011802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "The Garden Bed and Breakfast",
#             "photos": [
#                 {
#                     "height": 290,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105040278745451295681\">The Garden Bed and Breakfast</a>"
#                     ],
#                     "photo_reference": "ATtYBwIJcukEpoLQ6wVETcTy5cZIdxuQW5t0O7hvtYQNoI1duRe38wcN75ZLRT6f5LRXfuFvdvKN9edUnah0gKQ3zjqJ1am9-Cq9FuXnyPnkjz61KDGgBktxIgIrRFcyYnZE1nmUs6Fsp4YoI308VUtCTplx3TsA7E2a6SwfRRxYbi4y6A5J",
#                     "width": 591
#                 }
#             ],
#             "place_id": "ChIJffkepThiNFERfdZQ-v84OxI",
#             "plus_code": {
#                 "compound_code": "48M8+88 Delta Junction, AK, USA",
#                 "global_code": "93PP48M8+88"
#             },
#             "rating": 4.8,
#             "reference": "ChIJffkepThiNFERfdZQ-v84OxI",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 30,
#             "vicinity": "3103 Tanana Loop Exn, Delta Junction"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 64.0974059,
#                     "lng": -145.76057
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 64.0986974802915,
#                         "lng": -145.7597296697085
#                     },
#                     "southwest": {
#                         "lat": 64.09599951970849,
#                         "lng": -145.7624276302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Alaska Frontier Inn",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100198044322287067676\">Alaska Frontier Inn</a>"
#                     ],
#                     "photo_reference": "ATtYBwIO3LqhE2J2rZOPsCh6mtLI6zzW0lXLi8ViRb_NXO_i3AXfnzmtl_VEGEzFXKMFcv8p-uYY3AhHu9aah5v5H4u_zObXpkCsYooRe2uqvqlzRzWI1AJKXM3GLe3VXYeK-6mbGiofKjUXzsxXVNueJYGrncyCCGPJbza6EHAl4_i9YERB",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJ5xzsgRaJNFEReIUOwTbRxC0",
#             "plus_code": {
#                 "compound_code": "36WQ+XQ Delta Junction, AK, USA",
#                 "global_code": "93PP36WQ+XQ"
#             },
#             "reference": "ChIJ5xzsgRaJNFEReIUOwTbRxC0",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "3548 Richardson Highway, Delta Junction"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 64.2144067,
#                     "lng": -145.7845583
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 64.2156500302915,
#                         "lng": -145.7837561
#                     },
#                     "southwest": {
#                         "lat": 64.21295206970849,
#                         "lng": -145.7869649
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Quartz Lake Lodge and Cabins",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1536,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106632271512698934630\">Eric Collier</a>"
#                     ],
#                     "photo_reference": "ATtYBwK9vaOP1B3ETt_XH_yjg7XFrCXrK2rFpil5tAg5tV54pwgFUrRLhvd26V6Kw9BFalJ67iPzEmgiE6yCYt2PsLUWQ_ycHm4xOdCPmfDiRyS_4vDhsHliHg0BHZeU74AeQ5CHON4uTWJxClRE45Os6CNR40XPGNipdUSf7yMg3WqwfoTf",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJJQfvhW59NFERlhbnGdmmU_I",
#             "plus_code": {
#                 "compound_code": "6678+Q5 Big Delta, AK, USA",
#                 "global_code": "93PP6678+Q5"
#             },
#             "rating": 5,
#             "reference": "ChIJJQfvhW59NFERlhbnGdmmU_I",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2,
#             "vicinity": "Dot Lake"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 64.0532607,
#                     "lng": -145.7355566
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 64.0546323302915,
#                         "lng": -145.7341971197085
#                     },
#                     "southwest": {
#                         "lat": 64.05193436970849,
#                         "lng": -145.7368950802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/camping-71.png",
#             "name": "Delta State Recreation Site",
#             "photos": [
#                 {
#                     "height": 3999,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105272539284208792077\">Alaska Local Guide</a>"
#                     ],
#                     "photo_reference": "ATtYBwIZb5DdWKG1FeZizkYOzRSgPf8KLbC8HzRvGDlHyFPsyYpqZZTSvJCA7b7wXPQKD3yNOEf8UnMNIycNEvykQ2aSjNFeHKjPvIiFmtQR6rx916d6no6qo8AErKTQL4LVKhak9f-_pRCndfwBCO3xVr1d8Nz1uXuTHEd9Wb4-0vF2Xqj_",
#                     "width": 3999
#                 }
#             ],
#             "place_id": "ChIJrUFVbdOLNFERVpx8Y0JXyG8",
#             "plus_code": {
#                 "compound_code": "3737+8Q Delta Junction, AK, USA",
#                 "global_code": "93PP3737+8Q"
#             },
#             "rating": 4.3,
#             "reference": "ChIJrUFVbdOLNFERVpx8Y0JXyG8",
#             "scope": "GOOGLE",
#             "types": [
#                 "campground",
#                 "lodging",
#                 "park",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 26,
#             "vicinity": "Delta State Recreation Site Access Road, Delta Junction"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 64.0437002,
#                     "lng": -145.7300789
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 64.04509973029151,
#                         "lng": -145.7283108697085
#                     },
#                     "southwest": {
#                         "lat": 64.04240176970849,
#                         "lng": -145.7310088302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Delta Lodging",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3153,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110201642388573501368\">laura jennings</a>"
#                     ],
#                     "photo_reference": "ATtYBwJkWUWhicjUU2-N8RH0163aC6Sd_GcESLw4gzIrty8nOesCcB8QBqVJFctUQRab0q8Jb8_ZhjCTvhvwIIW4_o8wfs7CVzqNHjRn0idCDk77UUGtmzcxvygUOfV2vlCrTYjTbotvkBHYMC5ljSJkkQWccsWsVFA4uOmEMaf7TgBl5HTH",
#                     "width": 5184
#                 }
#             ],
#             "place_id": "ChIJnVzkusiLNFERKBgAWvqjj2U",
#             "plus_code": {
#                 "compound_code": "27V9+FX Delta Junction, AK, USA",
#                 "global_code": "93PP27V9+FX"
#             },
#             "rating": 4.5,
#             "reference": "ChIJnVzkusiLNFERKBgAWvqjj2U",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 10,
#             "vicinity": "2661 Richardson Avenue, Delta Junction"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 64.0327466,
#                     "lng": -145.7322783
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 64.03414518029152,
#                         "lng": -145.7302795697085
#                     },
#                     "southwest": {
#                         "lat": 64.0314472197085,
#                         "lng": -145.7329775302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Delta Accommodations - Richardson Suites",
#             "photos": [
#                 {
#                     "height": 794,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105416976000220818158\">LINDA SAMUEL</a>"
#                     ],
#                     "photo_reference": "ATtYBwKXFA-mFziUcHNZ7UjPAwjvN68KqCwtlRXX125XsQA-7JPduH-p2ToAWHNQnFFtyXjGkqyvG-2VleKshePO9jPy6mqXzSXXARDBvIeDhhErdAVhs02ireblrFBj7HJhP_JLhzmbzN1pTmJAfLNhube2BeYrOf4HX0V6lT1ev3hEHMv-",
#                     "width": 1059
#                 }
#             ],
#             "place_id": "ChIJQzJd0cCLNFERKeEZuXiRdkw",
#             "plus_code": {
#                 "compound_code": "27M9+33 Delta Junction, AK, USA",
#                 "global_code": "93PP27M9+33"
#             },
#             "reference": "ChIJQzJd0cCLNFERKeEZuXiRdkw",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Delta Junction"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 64.0401988,
#                     "lng": -145.7212977
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 64.04150803029151,
#                         "lng": -145.7199500197085
#                     },
#                     "southwest": {
#                         "lat": 64.0388100697085,
#                         "lng": -145.7226479802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Jillian House",
#             "place_id": "ChIJA7FdXciLNFERtvP1wd_FV7Q",
#             "plus_code": {
#                 "compound_code": "27RH+3F Delta Junction, AK, USA",
#                 "global_code": "93PP27RH+3F"
#             },
#             "reference": "ChIJA7FdXciLNFERtvP1wd_FV7Q",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "2185 Healy Street, Delta Junction"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 64.0401988,
#                     "lng": -145.7212977
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 64.04150803029151,
#                         "lng": -145.7199500197085
#                     },
#                     "southwest": {
#                         "lat": 64.0388100697085,
#                         "lng": -145.7226479802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Aurora Bed and Breakfast",
#             "photos": [
#                 {
#                     "height": 4000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110356397097389869416\">JalithLal KV</a>"
#                     ],
#                     "photo_reference": "ATtYBwLvBlJJLZxdPxLS9uEXqIsR7IEZxMReKLtmU5KSeYPWZTL2jAMFO6JZu8fbi9NUiSu97q1E6LKq0r-H4-PbqoP9AkwExL83ga0JizItw74mmXjVgMD3RULhuMiz2xm-DkEiKpRWuJ8aK2dWlZsYyrGBLzo4oMehnzqcbeJfvqUCrCPf",
#                     "width": 6000
#                 }
#             ],
#             "place_id": "ChIJA7FdXciLNFERQN_FA-wQqnA",
#             "plus_code": {
#                 "compound_code": "27RH+3F Delta Junction, AK, USA",
#                 "global_code": "93PP27RH+3F"
#             },
#             "rating": 2.5,
#             "reference": "ChIJA7FdXciLNFERQN_FA-wQqnA",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2,
#             "vicinity": "2185 Healy Street, Delta Junction"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 64.0332713,
#                     "lng": -145.7156545
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 64.0345897802915,
#                         "lng": -145.7143477197085
#                     },
#                     "southwest": {
#                         "lat": 64.03189181970849,
#                         "lng": -145.7170456802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Snowed Inn RV, Campers & Tents (Formerly Bergstad's RV & Trailer Court)",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2988,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109796095471713793450\">Steve Morris</a>"
#                     ],
#                     "photo_reference": "ATtYBwKYaC4G5tZt0x04Gwu0aWuE9RxDYsLR0MInOabUTUm807J8BnQZhhx6dWvEUN6BT0bLOU4tb7z7zoZD1uWV0cifUed3Zb8a3f0h1AG7SeGi9IQz1VE1jysKRUwz9lY6KhgQBpiGVT5xUdPHkrl8Y_tCqBJHAs8Ul3At_zEx7CIaGS4d",
#                     "width": 3984
#                 }
#             ],
#             "place_id": "ChIJ8-sYC7mLNFERIZaxR-OfBH8",
#             "plus_code": {
#                 "compound_code": "27MM+8P Delta Junction, AK, USA",
#                 "global_code": "93PP27MM+8P"
#             },
#             "rating": 3.9,
#             "reference": "ChIJ8-sYC7mLNFERIZaxR-OfBH8",
#             "scope": "GOOGLE",
#             "types": [
#                 "rv_park",
#                 "campground",
#                 "lodging",
#                 "park",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 36,
#             "vicinity": "1421 Alaska Highway, Delta Junction"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 64.0255813,
#                     "lng": -145.6799774
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 64.02692503029151,
#                         "lng": -145.6788959500001
#                     },
#                     "southwest": {
#                         "lat": 64.02422706970849,
#                         "lng": -145.68322175
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Trophy Lodge",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1080,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104165375885056239827\">Amy Macpherson</a>"
#                     ],
#                     "photo_reference": "ATtYBwI5c0p0ljXCzsb3Hp6T4kPqes4k9oFQOB5MJ1A3AjPrd8Y9aYBBKWD00jnaRiLSeyEjPlk8JdWW1u0rOMbw9OyFdr-b5IPt61ifUpsGMTciUImsyBcgzYaQKbPTSUtFvAxXpL90lgOhAB4cWUwgkeesoTxBmZU8eywsMc6kvUBX6kad",
#                     "width": 1920
#                 }
#             ],
#             "place_id": "ChIJE-8x2aeLNFERKkzT0bUILrg",
#             "plus_code": {
#                 "compound_code": "28GC+62 Delta Junction, AK, USA",
#                 "global_code": "93PP28GC+62"
#             },
#             "rating": 4.2,
#             "reference": "ChIJE-8x2aeLNFERKkzT0bUILrg",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 65,
#             "vicinity": "1420 Alaska Highway, Delta Junction"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 63.97083919999999,
#                     "lng": -145.7208069
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 63.9721881802915,
#                         "lng": -145.7194579197085
#                     },
#                     "southwest": {
#                         "lat": 63.96949021970849,
#                         "lng": -145.7221558802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "MDA Lodging",
#             "photos": [
#                 {
#                     "height": 3008,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116730643578465297516\">Tina Burch</a>"
#                     ],
#                     "photo_reference": "ATtYBwKB9nPuJx_a4383-RvEny0A7sdf2axtwpxUeOENIxqK3p2Xm8VlQ7f6HjZMFWHhyZtmWgwr0uuRi4ROsUrz6a41F2OQDYJfUlj1I7RcPw3sdbbWNBbRYc954VFezjoq9-bPdh4CRE3W6bVOeKy627h1tkx39DA8S0-n2OjB86LlK8Df",
#                     "width": 4000
#                 }
#             ],
#             "place_id": "ChIJvYl0zJSMNFERIPy9i6X1iZ8",
#             "plus_code": {
#                 "compound_code": "X7CH+8M Fort Greely, AK, USA",
#                 "global_code": "93MPX7CH+8M"
#             },
#             "rating": 4.2,
#             "reference": "ChIJvYl0zJSMNFERIPy9i6X1iZ8",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 20,
#             "vicinity": "Fort Greely"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 64.0569343,
#                     "lng": -145.5353866
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 64.05828338029151,
#                         "lng": -145.5339656197085
#                     },
#                     "southwest": {
#                         "lat": 64.05558541970849,
#                         "lng": -145.5366635802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Clearwater Creek Cabin",
#             "photos": [
#                 {
#                     "height": 1136,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103580876507161766069\">Rachel Helkenn</a>"
#                     ],
#                     "photo_reference": "ATtYBwI9iFdZkmZAJomyvfv7iFD9K2yFAZvuVYtswO1H9ATX1OwzkXVwhNC9-s0XmDQSPBkt7rCsSxDb8T1XA3bN0lOCuJ-AZly8G2DEWIypWDGbhocKDagRhlr_CVOlHr3DxjTaxCL0_UtWT7XSQcMy_MWFUCls1F6Xjb4tGQdTCKji_5DJ",
#                     "width": 640
#                 }
#             ],
#             "place_id": "ChIJTcUjFfFhNFERyPaP0hGfOjs",
#             "plus_code": {
#                 "compound_code": "3F47+QR Delta Junction, AK, USA",
#                 "global_code": "93PP3F47+QR"
#             },
#             "reference": "ChIJTcUjFfFhNFERyPaP0hGfOjs",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "2597 Dickson Road, Delta Junction"
#         }
#     ],
#     "status": "OK"
# }

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-165-464b2b3e63ad> in <module>
#      11 # Store the DataFrame Row
#      12 # NOTE: be sure to update with your DataFrame name
# ---> 13 hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
#      14 locations = hotel_df[["Lat", "Lng"]]
#
# <ipython-input-165-464b2b3e63ad> in <listcomp>(.0)
#      11 # Store the DataFrame Row
#      12 # NOTE: be sure to update with your DataFrame name
# ---> 13 hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
#      14 locations = hotel_df[["Lat", "Lng"]]
#
# KeyError: 'Hotel Name'

# %%
# Add marker layer ontop of heat map


# Display figure
