# %%
import pandas as pd
import numpy as np
import scipy.stats as st
from scipy.stats import linregress
import matplotlib.pyplot as plt

# Modules for handling APIs
import requests
import json

import time
from sys import exit


# Module for choosing city nearest to random coordinates (in lat/lon)
from citipy import citipy

# %%
api_key = ""

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

# %% [markdown]
# I wrote two custom functions to facilitate data retrieval from *OpenWeather*:
#
# 1. weather_batch()
#
# 2. multiple_batches()
#
# ***
#
# **weather_batch()** retrieves a specified number of weather records from *OpenWeather*.
#
#     parameters::
#     city_count: the number of coordinates that will be used to find the nearest city
#     your_url: the url with api_key, formatted for the API
#
#     weather_batch() uses two helper functions:
#
#     a. city_df_maker()
#     b. weather_grabber()
#
#     city_df_maker(): generates random lat/lon coordinates using 'numpy'.
#         * The number of random coordinates is based on the city_count argument from weather_batch().
#         * It uses 'citipy' to retrieve the nearest city to each coordinate pair.
#         * It returns a 'pandas' DataFrame object with lat, lon, and the corresponding name of the city.
#
#     weather_grabber(): uses 'requests' to fetch the weather data from the API in json format.
#         * It merges the weather data with the lat/lon data and returns a 'pandas' DataFrame object.
#
#
# **multiple_batches()** uses weather_batch() to call multiple batches of weather data from the API.
#
#     parameters::
#     city_count_multiple: argument to be used for city_count from weather_batch(); max = 60/batch
#     your_url_multiple: argument to be used for your_url in weather_batch())
#     batches: the number of batches
#     sleep_time: time delay between batches in seconds (via the 'time')
#
#     To limit the number of calls/minute, the function calls exit from 'sys' if city_count_multiple is greater than 60.
#
#     multiple_batches() returns a 'pandas' DataFrame of length city_count_multiple * batches.
#
#     Duplicate cities are removed from the DataFrame based on the "city" column.

# %%
# Run this cell

# START
def weather_batch(city_count, your_url):
    
    print(f"Attempting to retrieve {city_count} records in this batch.\n")
    
    initial_count = city_count
    
    #--------------------#

    def city_df_maker(target_count):
    
        lat_range = np.arange(-90.00, 90.00, 0.01)
        lon_range = np.arange(-180.00, 180.00, 0.01)

        lats = np.random.choice(lat_range, target_count)
        lons = np.random.choice(lon_range, target_count)

        lat_lon_df = pd.DataFrame({"latitude" : lats, 
                                   "longitude" : lons})
 
        cities = [None] * len(lat_lon_df)

        for i in range(len(lat_lon_df)):
            cities[i] = citipy.nearest_city(lat_lon_df.iloc[i][0], lat_lon_df.iloc[i][1]).city_name.capitalize()

        lat_lon_df["city"] = cities    
        
        return lat_lon_df
    
    #--------------------#                                                              
    
    city_df_temp = city_df_maker(initial_count)
                                   
    #--------------------# 
    
    
    def weather_grabber(city_df, url_arg):
    
        city_df.set_index("city", inplace = True)
        city_list_temp = city_df.index.to_list()    
        
        max_temp = []
        humidity = []
        cloudiness = []
        wind_speed = []
        bad_cities = []
        country = []
        date = []
    
        for city_name in city_list_temp:
            response_temp = requests.get(url_arg + city_name)
            response_temp_json = response_temp.json()
    
            try:
                max_temp.append(response_temp_json["main"]["temp_max"])
                humidity.append(response_temp_json["main"]["humidity"])
                cloudiness.append(response_temp_json["clouds"]["all"])
                wind_speed.append(response_temp_json["wind"]["speed"])
                country.append(response_temp_json["sys"]["country"])
                date.append(response_temp_json["dt"])
                print(f"All temperature data for {city_name} found! Appending stats.")
        
            except Exception as e:
                print(f"Exception type: {e}")
                bad_cities.append(city_name)
                print(f"Temperature data for {city_name} was not found. Skipping this city.")
                pass
        
        for bad_city in bad_cities:
            city_list_temp.remove(bad_city)
        
        weather_df = pd.DataFrame({"city":city_list_temp, 
                                   "max_temp":max_temp, 
                                   "humidity":humidity,
                                   "cloud_cover":cloudiness, 
                                   "wind_speed":wind_speed, 
                                   "country":country,
                                   "date":date})
        
        weather_df["city"] = weather_df["city"].astype(str)
        
        city_df = city_df.drop(bad_cities)
        city_df = city_df.reset_index()
        city_df["city"] = city_df["city"].astype(str)
        
        weather_merged_df = pd.merge(city_df, weather_df, on = "city")
        
        return weather_merged_df   
    
    #--------------------# 

    weather_out_df = weather_grabber(city_df_temp, your_url)
    weather_out_df = weather_out_df.drop_duplicates(subset = "city", keep = "first")
    weather_out_df = weather_out_df.loc[weather_out_df["humidity"] <= 100]
    
    while len(weather_out_df) < initial_count:
        print("\n")
        print("Accounting for duplicate cities (or errant humidity measurements) within the batch.\n")
        new_city_df =  city_df_maker(initial_count - len(weather_out_df))
        weather_out_df_temp = weather_grabber(new_city_df, your_url)
        weather_out_df = pd.concat([weather_out_df, weather_out_df_temp])
        weather_out_df = weather_out_df.drop_duplicates(subset = "city", keep = "first")
        weather_out_df = weather_out_df.loc[weather_out_df["humidity"] <= 100]
    
    print(f"Success: returning DataFrame of length: {len(weather_out_df)}.")
    
    return weather_out_df.reset_index(drop = True)
# End

# %%
# Run this cell

# START
def multiple_batches(city_count_multiple, your_url_multiple, batches, sleep_time):
    
    if city_count_multiple > 60:
        print("The maximum number of calls/minute with your free API key is 60.")
        print("Call the function again with batches <= 60 to continue.")
        exit()
    
    records_goal = city_count_multiple * batches 
    
    print(f"Attempting to call a total of {records_goal} records, in batches of {batches}.")
    print(f"There will be a time delay of {sleep_time} seconds after each batch.\n")
              
    batch_list = []

    print("--------------------------------------------------")
    print("--------------------------------------------------\n")
    print("Batch 1.\n")
    batch_list.append(weather_batch(city_count_multiple, your_url_multiple))
    print("--------------------------------------------------\n")
    time.sleep(sleep_time) 
    
    for i in range(2, batches + 1):
        print(f"Batch {i}.\n")
        batch_list.append(weather_batch(city_count_multiple, your_url_multiple))
        print("--------------------------------------------------\n")
        time.sleep(sleep_time)
    
    output_df = pd.concat(batch_list)
    output_df.drop_duplicates(subset = "city", keep = "first", inplace = True)
    
    print("\n")
    print("--------------------------------------------------")
    print("--------------------------------------------------")
   
    while len(output_df) < records_goal:
        print("\n")
        print(f"There were some duplicate cities (or errant humidity measurements) when the batches were combined.")
        missing_record_count =  records_goal - len(output_df)
        print(f"Number of missing records after dropping duplicates: {missing_record_count}.\n")
        extra_temps_df = weather_batch(missing_record_count, your_url_multiple)
        output_df = pd.concat([output_df, extra_temps_df])
        output_df.drop_duplicates(subset = "city", keep = "first", inplace = True)
        output_df = output_df.loc[output_df["humidity"] <= 100]
    
    print("\n")
    print(f"Weather data for a total of {len(output_df)} cities have been retrieved.")
    print(f"Your query is complete!")
    
    return output_df.reset_index(drop = True)
# END

# %%
# Creating a DataFrame of length 500 (in 10 batches of 50, with a time delay of 61 seconds between batches)
weather_batch_all = multiple_batches(50, query_url, 10, 61)
# Out:
# Attempting to call a total of 500 records, in batches of 10.
# There will be a time delay of 61 seconds after each batch.
#
# --------------------------------------------------
# --------------------------------------------------
#
# Batch 1.
#
# Attempting to retrieve 50 records in this batch.
#
# All temperature data for Mar del plata found! Appending stats.
# Exception type: 'main'
# Temperature data for Barentsburg was not found. Skipping this city.
# All temperature data for Rikitea found! Appending stats.
# Exception type: 'main'
# Temperature data for Taolanaro was not found. Skipping this city.
# All temperature data for Fare found! Appending stats.
# Exception type: 'main'
# Temperature data for Illoqqortoormiut was not found. Skipping this city.
# All temperature data for Saldanha found! Appending stats.
# All temperature data for San policarpo found! Appending stats.
# All temperature data for Port hueneme found! Appending stats.
# All temperature data for Sorong found! Appending stats.
# All temperature data for Port lincoln found! Appending stats.
# All temperature data for Butaritari found! Appending stats.
# All temperature data for Mar del plata found! Appending stats.
# All temperature data for Nikolskoye found! Appending stats.
# Exception type: 'main'
# Temperature data for Taolanaro was not found. Skipping this city.
# All temperature data for Belmonte found! Appending stats.
# All temperature data for Punta arenas found! Appending stats.
# All temperature data for Cidreira found! Appending stats.
# All temperature data for Zhigansk found! Appending stats.
# Exception type: 'main'
# Temperature data for Miranorte was not found. Skipping this city.
# All temperature data for Comodoro rivadavia found! Appending stats.
# All temperature data for Atuona found! Appending stats.
# All temperature data for Qaanaaq found! Appending stats.
# All temperature data for Lang son found! Appending stats.
# All temperature data for Lebu found! Appending stats.
# All temperature data for Kaitangata found! Appending stats.
# All temperature data for Mildura found! Appending stats.
# All temperature data for Rikitea found! Appending stats.
# All temperature data for Albany found! Appending stats.
# All temperature data for Calabozo found! Appending stats.
# All temperature data for Hilo found! Appending stats.
# All temperature data for Alice springs found! Appending stats.
# All temperature data for Severo-kurilsk found! Appending stats.
# Exception type: 'main'
# Temperature data for Samalaeulu was not found. Skipping this city.
# All temperature data for Jibuti found! Appending stats.
# Exception type: 'main'
# Temperature data for Grand river south east was not found. Skipping this city.
# All temperature data for Tasiilaq found! Appending stats.
# All temperature data for Tiksi found! Appending stats.
# All temperature data for Conceicao do araguaia found! Appending stats.
# All temperature data for Eckernforde found! Appending stats.
# All temperature data for Atuona found! Appending stats.
# All temperature data for Churapcha found! Appending stats.
# Exception type: 'main'
# Temperature data for Grand river south east was not found. Skipping this city.
# All temperature data for Nanortalik found! Appending stats.
# All temperature data for Cape town found! Appending stats.
# Exception type: 'main'
# Temperature data for Taolanaro was not found. Skipping this city.
# All temperature data for Tuktoyaktuk found! Appending stats.
# All temperature data for Severo-kurilsk found! Appending stats.
# All temperature data for Mao found! Appending stats.
# All temperature data for Tabuk found! Appending stats.
#
#
# Accounting for duplicate cities (or errant humidity measurements) within the batch.
#
# All temperature data for Tucson found! Appending stats.
# All temperature data for Yellowknife found! Appending stats.
# All temperature data for Mahebourg found! Appending stats.
# All temperature data for Cherskiy found! Appending stats.
# All temperature data for Samarai found! Appending stats.
# All temperature data for Bronnoysund found! Appending stats.
# All temperature data for Hithadhoo found! Appending stats.
# All temperature data for Mutsu found! Appending stats.
# All temperature data for Huarmey found! Appending stats.
# All temperature data for Punta arenas found! Appending stats.
# All temperature data for Ushuaia found! Appending stats.
# All temperature data for Nortelandia found! Appending stats.
# Exception type: 'main'
# Temperature data for Barentsburg was not found. Skipping this city.
#
#
# Accounting for duplicate cities (or errant humidity measurements) within the batch.
#
# All temperature data for Ibicarai found! Appending stats.
# All temperature data for Bowen found! Appending stats.
# Success: returning DataFrame of length: 50.
# --------------------------------------------------
#
# Batch 2.
#
# Attempting to retrieve 50 records in this batch.
#
# All temperature data for Cairns found! Appending stats.
# All temperature data for Saquarema found! Appending stats.
# All temperature data for Busselton found! Appending stats.
# All temperature data for Busselton found! Appending stats.
# All temperature data for Bredasdorp found! Appending stats.
# All temperature data for Hermanus found! Appending stats.
# All temperature data for Shingu found! Appending stats.
# All temperature data for Srednekolymsk found! Appending stats.
# All temperature data for Alofi found! Appending stats.
# All temperature data for Los llanos de aridane found! Appending stats.
# All temperature data for Rikitea found! Appending stats.
# All temperature data for Broome found! Appending stats.
# Exception type: 'main'
# Temperature data for Illoqqortoormiut was not found. Skipping this city.
# All temperature data for Ribeira grande found! Appending stats.
# All temperature data for Kaitangata found! Appending stats.
# All temperature data for Moratuwa found! Appending stats.
# Exception type: 'main'
# Temperature data for Utiroa was not found. Skipping this city.
# All temperature data for Penzance found! Appending stats.
# Exception type: 'main'
# Temperature data for Mys shmidta was not found. Skipping this city.
# All temperature data for Atuona found! Appending stats.
# All temperature data for Punta arenas found! Appending stats.
# Exception type: 'main'
# Temperature data for Attawapiskat was not found. Skipping this city.
# All temperature data for Clinton found! Appending stats.
# All temperature data for Hermanus found! Appending stats.
# All temperature data for Eureka found! Appending stats.
# All temperature data for Rikitea found! Appending stats.
# Exception type: 'main'
# Temperature data for Saleaula was not found. Skipping this city.
# All temperature data for Gat found! Appending stats.
# All temperature data for Atuona found! Appending stats.
# All temperature data for Butaritari found! Appending stats.
# All temperature data for Freeport found! Appending stats.
# All temperature data for Komsomolskiy found! Appending stats.
# All temperature data for Ushuaia found! Appending stats.
# All temperature data for Graham found! Appending stats.
# All temperature data for Saint-augustin found! Appending stats.
# All temperature data for Leningradskiy found! Appending stats.
# All temperature data for General roca found! Appending stats.
# Exception type: 'main'
# Temperature data for Taolanaro was not found. Skipping this city.
# Exception type: 'main'
# Temperature data for Sindand was not found. Skipping this city.
# All temperature data for Vanimo found! Appending stats.
# All temperature data for Whitehorse found! Appending stats.
# All temperature data for Luderitz found! Appending stats.
# All temperature data for At-bashi found! Appending stats.
# All temperature data for Ongandjera found! Appending stats.
# All temperature data for Iqaluit found! Appending stats.
# All temperature data for Niksar found! Appending stats.
# All temperature data for Zalantun found! Appending stats.
# All temperature data for Mataura found! Appending stats.
# All temperature data for Tuktoyaktuk found! Appending stats.
# All temperature data for Dikson found! Appending stats.
#
#
# Accounting for duplicate cities (or errant humidity measurements) within the batch.
#
# All temperature data for Puerto ayora found! Appending stats.
# All temperature data for Dikson found! Appending stats.
# All temperature data for Dikson found! Appending stats.
# All temperature data for Amga found! Appending stats.
# All temperature data for Hermanus found! Appending stats.
# All temperature data for Ushuaia found! Appending stats.
# All temperature data for Birao found! Appending stats.
# All temperature data for Kosh-agach found! Appending stats.
# All temperature data for Turukhansk found! Appending stats.
# All temperature data for Butaritari found! Appending stats.
# Exception type: 'main'
# Temperature data for Belushya guba was not found. Skipping this city.
#
#
# Accounting for duplicate cities (or errant humidity measurements) within the batch.
#
# All temperature data for Aragarcas found! Appending stats.
# All temperature data for Korla found! Appending stats.
# All temperature data for Quatre cocos found! Appending stats.
# All temperature data for Albany found! Appending stats.
# All temperature data for Necochea found! Appending stats.
# All temperature data for Gigmoto found! Appending stats.
# Success: returning DataFrame of length: 50.
# --------------------------------------------------
#
# Batch 3.
#
# Attempting to retrieve 50 records in this batch.
#
# All temperature data for Hilo found! Appending stats.
# All temperature data for Ribeira grande found! Appending stats.
# All temperature data for Albany found! Appending stats.
# All temperature data for Omboue found! Appending stats.
# All temperature data for Cape town found! Appending stats.
# All temperature data for East london found! Appending stats.
# All temperature data for Fort abbas found! Appending stats.
# All temperature data for Tampere found! Appending stats.
# All temperature data for Ushuaia found! Appending stats.
# Exception type: 'main'
# Temperature data for Hihifo was not found. Skipping this city.
# All temperature data for Ostrovnoy found! Appending stats.
# All temperature data for Montepuez found! Appending stats.
# All temperature data for Mar del plata found! Appending stats.
# All temperature data for Rikitea found! Appending stats.
# All temperature data for Campos belos found! Appending stats.
# All temperature data for Hithadhoo found! Appending stats.
# All temperature data for Kibala found! Appending stats.
# All temperature data for New norfolk found! Appending stats.
# All temperature data for El alto found! Appending stats.
# All temperature data for Avarua found! Appending stats.
# All temperature data for Butaritari found! Appending stats.
# All temperature data for Punta arenas found! Appending stats.
# All temperature data for Vao found! Appending stats.
# All temperature data for Port alfred found! Appending stats.
# All temperature data for Port alfred found! Appending stats.
# Exception type: 'main'
# Temperature data for Palabuhanratu was not found. Skipping this city.
# All temperature data for Sakakah found! Appending stats.
# All temperature data for Busselton found! Appending stats.
# Exception type: 'main'
# Temperature data for Xiongshi was not found. Skipping this city.
# All temperature data for Cape town found! Appending stats.
# All temperature data for Jamestown found! Appending stats.
# All temperature data for Santa rosa found! Appending stats.
# All temperature data for Nikolskoye found! Appending stats.
# All temperature data for Kaitangata found! Appending stats.
# All temperature data for Vaitape found! Appending stats.
# All temperature data for Busselton found! Appending stats.
# All temperature data for Touros found! Appending stats.
# All temperature data for Shimoda found! Appending stats.
# All temperature data for Ekibastuz found! Appending stats.
# All temperature data for Lalawigan found! Appending stats.
# All temperature data for Lebu found! Appending stats.
# All temperature data for Santa rosa found! Appending stats.
# All temperature data for Qaanaaq found! Appending stats.
# All temperature data for Bambous virieux found! Appending stats.
# Exception type: 'main'
# Temperature data for Sorvag was not found. Skipping this city.
# All temperature data for Bassano found! Appending stats.
# All temperature data for Ola found! Appending stats.
# All temperature data for Tiksi found! Appending stats.
# All temperature data for Lata found! Appending stats.
# All temperature data for Ushuaia found! Appending stats.
#
#
# Accounting for duplicate cities (or errant humidity measurements) within the batch.
#
# All temperature data for Hals found! Appending stats.
# All temperature data for Hobart found! Appending stats.
# All temperature data for Sisimiut found! Appending stats.
# All temperature data for Rikitea found! Appending stats.
# All temperature data for Suntar found! Appending stats.
# All temperature data for Hovd found! Appending stats.
# All temperature data for Atuona found! Appending stats.
# All temperature data for Hobyo found! Appending stats.
# All temperature data for Nanortalik found! Appending stats.
#
#
# Accounting for duplicate cities (or errant humidity measurements) within the batch.
#
# Exception type: 'main'
# Temperature data for Attawapiskat was not found. Skipping this city.
#
#
# Accounting for duplicate cities (or errant humidity measurements) within the batch.
#
# All temperature data for Coahuayana found! Appending stats.
# Success: returning DataFrame of length: 50.
# --------------------------------------------------
#
# Batch 4.
#
# Attempting to retrieve 50 records in this batch.
#
# All temperature data for Bethel found! Appending stats.
# All temperature data for Qaanaaq found! Appending stats.
# All temperature data for Griffith found! Appending stats.
# All temperature data for Upernavik found! Appending stats.
# All temperature data for Punta arenas found! Appending stats.
# All temperature data for Ribeira grande found! Appending stats.
# All temperature data for Saint-philippe found! Appending stats.
# All temperature data for Ushuaia found! Appending stats.
# All temperature data for Hobart found! Appending stats.
# All temperature data for Beirut found! Appending stats.
# All temperature data for Hasaki found! Appending stats.
# All temperature data for Bluff found! Appending stats.
# All temperature data for Busselton found! Appending stats.
# All temperature data for Albany found! Appending stats.
# All temperature data for Broken hill found! Appending stats.
# All temperature data for Kidal found! Appending stats.
# All temperature data for Panukulan found! Appending stats.
# All temperature data for Isangel found! Appending stats.
# All temperature data for Atuona found! Appending stats.
# All temperature data for Georgetown found! Appending stats.
# All temperature data for Port hardy found! Appending stats.
# All temperature data for Atuona found! Appending stats.
# All temperature data for Lebu found! Appending stats.
# All temperature data for Ceres found! Appending stats.
# All temperature data for Tessalit found! Appending stats.
# Exception type: 'main'
# Temperature data for Juifang was not found. Skipping this city.
# All temperature data for Tagusao found! Appending stats.
# All temperature data for Mataura found! Appending stats.
# All temperature data for Tuktoyaktuk found! Appending stats.
# Exception type: 'main'
# Temperature data for Taolanaro was not found. Skipping this city.
# All temperature data for Lagoa found! Appending stats.
# All temperature data for Aykhal found! Appending stats.
# All temperature data for Yenagoa found! Appending stats.
# All temperature data for Hobart found! Appending stats.
# All temperature data for Katsuura found! Appending stats.
# All temperature data for Busselton found! Appending stats.
# All temperature data for Mayo found! Appending stats.
# All temperature data for Aklavik found! Appending stats.
# All temperature data for Airai found! Appending stats.
# All temperature data for Georgiyevka found! Appending stats.
# All temperature data for Haines junction found! Appending stats.
# All temperature data for Tasiilaq found! Appending stats.
# All temperature data for Rikitea found! Appending stats.
# All temperature data for Ostrovnoy found! Appending stats.
# All temperature data for Xining found! Appending stats.
# Exception type: 'main'
# Temperature data for Tsihombe was not found. Skipping this city.
# All temperature data for Manono found! Appending stats.
# All temperature data for Busselton found! Appending stats.
# All temperature data for Netarhat found! Appending stats.
# All temperature data for Rikitea found! Appending stats.
#
#
# Accounting for duplicate cities (or errant humidity measurements) within the batch.
#
# All temperature data for Busselton found! Appending stats.
# All temperature data for Yellowknife found! Appending stats.
# All temperature data for Uttaradit found! Appending stats.
# All temperature data for Puerto ayora found! Appending stats.
# All temperature data for Souillac found! Appending stats.
# All temperature data for Punta arenas found! Appending stats.
# All temperature data for Hobart found! Appending stats.
# All temperature data for Georgetown found! Appending stats.
#
#
# Accounting for duplicate cities (or errant humidity measurements) within the batch.
#
# All temperature data for Pisco found! Appending stats.
# All temperature data for Provideniya found! Appending stats.
# All temperature data for Faanui found! Appending stats.
# All temperature data for Rikitea found! Appending stats.
#
#
# Accounting for duplicate cities (or errant humidity measurements) within the batch.
#
# Exception type: 'main'
# Temperature data for Tumannyy was not found. Skipping this city.
#
#
# Accounting for duplicate cities (or errant humidity measurements) within the batch.
#
# All temperature data for Worcester found! Appending stats.
# Success: returning DataFrame of length: 50.
# --------------------------------------------------
#
# Batch 5.
#
# Attempting to retrieve 50 records in this batch.
#
# All temperature data for Tasiilaq found! Appending stats.
# All temperature data for Hilo found! Appending stats.
# All temperature data for Lompoc found! Appending stats.
# All temperature data for Ushuaia found! Appending stats.
# All temperature data for Tupiza found! Appending stats.
# All temperature data for Rikitea found! Appending stats.
# All temperature data for Abu dhabi found! Appending stats.
# All temperature data for Fortuna found! Appending stats.
# All temperature data for Vuktyl found! Appending stats.
# All temperature data for Port alfred found! Appending stats.
# All temperature data for Yellowknife found! Appending stats.
# All temperature data for Oyek found! Appending stats.
# All temperature data for Belokurikha found! Appending stats.
# All temperature data for Hilo found! Appending stats.
# All temperature data for Vaini found! Appending stats.
# All temperature data for Mount gambier found! Appending stats.
# All temperature data for Kapaa found! Appending stats.
# All temperature data for Mahebourg found! Appending stats.
# All temperature data for Lavrentiya found! Appending stats.
# Exception type: 'main'
# Temperature data for Taolanaro was not found. Skipping this city.
# All temperature data for Saint george found! Appending stats.
# All temperature data for West wendover found! Appending stats.
# Exception type: 'main'
# Temperature data for Halalo was not found. Skipping this city.
# All temperature data for Priyutovo found! Appending stats.
# All temperature data for Palafrugell found! Appending stats.
# All temperature data for Maneadero found! Appending stats.
# All temperature data for Shubarkuduk found! Appending stats.
# All temperature data for Bloemfontein found! Appending stats.
# All temperature data for Torres found! Appending stats.
# All temperature data for Raga found! Appending stats.
# All temperature data for Punta arenas found! Appending stats.
# Exception type: 'main'
# Temperature data for Sentyabrskiy was not found. Skipping this city.
# All temperature data for Fereydunshahr found! Appending stats.
# All temperature data for Albany found! Appending stats.
# All temperature data for Mar del plata found! Appending stats.
# All temperature data for Jamestown found! Appending stats.
# All temperature data for Busselton found! Appending stats.
# All temperature data for Vaini found! Appending stats.
# All temperature data for Zavodoukovsk found! Appending stats.
# All temperature data for Nome found! Appending stats.
# All temperature data for Atuona found! Appending stats.
# Exception type: 'main'
# Temperature data for Chagda was not found. Skipping this city.
# All temperature data for Chokurdakh found! Appending stats.
# Exception type: 'main'
# Temperature data for Taolanaro was not found. Skipping this city.
# All temperature data for Zabaykalsk found! Appending stats.
# All temperature data for Rikitea found! Appending stats.
# All temperature data for Phultala found! Appending stats.
# All temperature data for Matara found! Appending stats.
# All temperature data for Asyut found! Appending stats.
# All temperature data for Isangel found! Appending stats.
#
#
# Accounting for duplicate cities (or errant humidity measurements) within the batch.
#
# All temperature data for Punta arenas found! Appending stats.
# All temperature data for Saint george found! Appending stats.
# All temperature data for Saint-georges found! Appending stats.
# All temperature data for Chokurdakh found! Appending stats.
# All temperature data for Lebu found! Appending stats.
# All temperature data for Hasaki found! Appending stats.
# All temperature data for Vaini found! Appending stats.
# All temperature data for Ushuaia found! Appending stats.
#
#
# Accounting for duplicate cities (or errant humidity measurements) within the batch.
#
# All temperature data for Cap malheureux found! Appending stats.
# All temperature data for Ushuaia found! Appending stats.
# All temperature data for Saskylakh found! Appending stats.
# All temperature data for Butaritari found! Appending stats.
# All temperature data for Airai found! Appending stats.
#
#
# Accounting for duplicate cities (or errant humidity measurements) within the batch.
#
# All temperature data for Goundam found! Appending stats.
# Success: returning DataFrame of length: 50.
# --------------------------------------------------
#
# Batch 6.
#
# Attempting to retrieve 50 records in this batch.
#
# All temperature data for Mayor pablo lagerenza found! Appending stats.
# All temperature data for Grindavik found! Appending stats.
# All temperature data for Kavieng found! Appending stats.
# All temperature data for Punta arenas found! Appending stats.
# All temperature data for Kapaa found! Appending stats.
# All temperature data for Yellowknife found! Appending stats.
# All temperature data for Kodiak found! Appending stats.
# All temperature data for Esperance found! Appending stats.
# All temperature data for Almaznyy found! Appending stats.
# All temperature data for Kodiak found! Appending stats.
# All temperature data for Ushuaia found! Appending stats.
# All temperature data for Yellowknife found! Appending stats.
# All temperature data for Antalaha found! Appending stats.
# All temperature data for Katsuura found! Appending stats.
# All temperature data for Inhambane found! Appending stats.
# All temperature data for Lasa found! Appending stats.
# All temperature data for Luderitz found! Appending stats.
# All temperature data for Jalu found! Appending stats.
# All temperature data for Cidreira found! Appending stats.
# All temperature data for Punta arenas found! Appending stats.
# All temperature data for Saskylakh found! Appending stats.
# All temperature data for Oranjemund found! Appending stats.
# All temperature data for Ribeira grande found! Appending stats.
# All temperature data for Bluff found! Appending stats.
# All temperature data for Kapaa found! Appending stats.
# Exception type: 'main'
# Temperature data for Vaitupu was not found. Skipping this city.
# All temperature data for Castro found! Appending stats.
# All temperature data for Coihaique found! Appending stats.
# All temperature data for Solnechnyy found! Appending stats.
# All temperature data for Ostrovnoy found! Appending stats.
# All temperature data for Asau found! Appending stats.
# All temperature data for Kut chap found! Appending stats.
# All temperature data for Arona found! Appending stats.
# All temperature data for Bluff found! Appending stats.
# All temperature data for Gamba found! Appending stats.
# All temperature data for Upernavik found! Appending stats.
# All temperature data for Portland found! Appending stats.
# All temperature data for Hobyo found! Appending stats.
# All temperature data for Atuona found! Appending stats.
# All temperature data for Hobart found! Appending stats.
# All temperature data for Krasnokamensk found! Appending stats.
# All temperature data for Ushuaia found! Appending stats.
# All temperature data for Seoul found! Appending stats.
# All temperature data for Husavik found! Appending stats.
# All temperature data for Kyshtovka found! Appending stats.
# All temperature data for Rikitea found! Appending stats.
# All temperature data for Ushuaia found! Appending stats.
# All temperature data for Atuona found! Appending stats.
# All temperature data for Castro found! Appending stats.
# All temperature data for Busselton found! Appending stats.
#
#
# Accounting for duplicate cities (or errant humidity measurements) within the batch.
#
# All temperature data for Rikitea found! Appending stats.
# All temperature data for Mahebourg found! Appending stats.
# All temperature data for Dikson found! Appending stats.
# All temperature data for Cabo san lucas found! Appending stats.
# All temperature data for Tasiilaq found! Appending stats.
# All temperature data for Isiolo found! Appending stats.
# All temperature data for Port hedland found! Appending stats.
# All temperature data for Bluff found! Appending stats.
# All temperature data for Aklavik found! Appending stats.
# All temperature data for Dikson found! Appending stats.
#
#
# Accounting for duplicate cities (or errant humidity measurements) within the batch.
#
# All temperature data for Henties bay found! Appending stats.
# All temperature data for Jaru found! Appending stats.
# All temperature data for Poum found! Appending stats.
# Success: returning DataFrame of length: 50.
# --------------------------------------------------
#
# Batch 7.
#
# Attempting to retrieve 50 records in this batch.
#
# All temperature data for Thompson found! Appending stats.
# All temperature data for Araouane found! Appending stats.
# All temperature data for Kununurra found! Appending stats.
# All temperature data for Tadine found! Appending stats.
# All temperature data for Vaini found! Appending stats.
# All temperature data for High rock found! Appending stats.
# Exception type: 'main'
# Temperature data for Grand river south east was not found. Skipping this city.
# All temperature data for Punta arenas found! Appending stats.
# All temperature data for Namibe found! Appending stats.
# All temperature data for Punta arenas found! Appending stats.
# All temperature data for Mataura found! Appending stats.
# Exception type: 'main'
# Temperature data for Vastervik was not found. Skipping this city.
# All temperature data for Longyearbyen found! Appending stats.
# All temperature data for Yellowknife found! Appending stats.
# All temperature data for Tuktoyaktuk found! Appending stats.
# All temperature data for Zyryanka found! Appending stats.
# All temperature data for Beringovskiy found! Appending stats.
# All temperature data for Yellowknife found! Appending stats.
# All temperature data for Carauari found! Appending stats.
# All temperature data for Kapaa found! Appending stats.
# Exception type: 'main'
# Temperature data for Rungata was not found. Skipping this city.
# All temperature data for Mar del plata found! Appending stats.
# All temperature data for Qaanaaq found! Appending stats.
# All temperature data for Barrow found! Appending stats.
# All temperature data for Cabo san lucas found! Appending stats.
# All temperature data for Rikitea found! Appending stats.
# All temperature data for Presidencia roque saenz pena found! Appending stats.
# All temperature data for Tilichiki found! Appending stats.
# All temperature data for Shimanovsk found! Appending stats.
# All temperature data for Biak found! Appending stats.
# All temperature data for Hobyo found! Appending stats.
# All temperature data for Busselton found! Appending stats.
# All temperature data for Jamestown found! Appending stats.
# All temperature data for Fevik found! Appending stats.
# All temperature data for Ukiah found! Appending stats.
# All temperature data for Jardim found! Appending stats.
# All temperature data for Windhoek found! Appending stats.
# All temperature data for Albany found! Appending stats.
# All temperature data for Yumen found! Appending stats.
# All temperature data for Butaritari found! Appending stats.
# All temperature data for Kurchum found! Appending stats.
# All temperature data for Kavieng found! Appending stats.
# All temperature data for Jamestown found! Appending stats.
# All temperature data for Bubaque found! Appending stats.
# All temperature data for Hermanus found! Appending stats.
# All temperature data for Bredasdorp found! Appending stats.
# All temperature data for Ponta do sol found! Appending stats.
# All temperature data for Severo-yeniseyskiy found! Appending stats.
# All temperature data for Busselton found! Appending stats.
# All temperature data for Bengkulu found! Appending stats.
#
#
# Accounting for duplicate cities (or errant humidity measurements) within the batch.
#
# All temperature data for Busselton found! Appending stats.
# All temperature data for Tilichiki found! Appending stats.
# All temperature data for Busselton found! Appending stats.
# All temperature data for Rikitea found! Appending stats.
# All temperature data for Atuona found! Appending stats.
# All temperature data for Ushuaia found! Appending stats.
# All temperature data for Bethel found! Appending stats.
#
#
# Accounting for duplicate cities (or errant humidity measurements) within the batch.
#
# All temperature data for Rikitea found! Appending stats.
# Exception type: 'main'
# Temperature data for Taolanaro was not found. Skipping this city.
# All temperature data for Alofi found! Appending stats.
# All temperature data for Arlit found! Appending stats.
#
#
# Accounting for duplicate cities (or errant humidity measurements) within the batch.
#
# All temperature data for Oga found! Appending stats.
# All temperature data for Aykhal found! Appending stats.
# Success: returning DataFrame of length: 50.
# --------------------------------------------------
#
# Batch 8.
#
# Attempting to retrieve 50 records in this batch.
#
# All temperature data for Deputatskiy found! Appending stats.
# All temperature data for Lensk found! Appending stats.
# All temperature data for Kodiak found! Appending stats.
# All temperature data for Bredasdorp found! Appending stats.
# All temperature data for San pedro found! Appending stats.
# All temperature data for Castro found! Appending stats.
# All temperature data for Miraflores found! Appending stats.
# All temperature data for Kropotkin found! Appending stats.
# All temperature data for Busselton found! Appending stats.
# All temperature data for Vaini found! Appending stats.
# All temperature data for Hilo found! Appending stats.
# All temperature data for Ancud found! Appending stats.
# All temperature data for Qaanaaq found! Appending stats.
# All temperature data for East london found! Appending stats.
# All temperature data for Tuktoyaktuk found! Appending stats.
# All temperature data for Mar del plata found! Appending stats.
# Exception type: 'main'
# Temperature data for Illoqqortoormiut was not found. Skipping this city.
# Exception type: 'main'
# Temperature data for Grand river south east was not found. Skipping this city.
# All temperature data for Kiunga found! Appending stats.
# All temperature data for Busselton found! Appending stats.
# All temperature data for Port elizabeth found! Appending stats.
# All temperature data for Kapaa found! Appending stats.
# All temperature data for Bluff found! Appending stats.
# All temperature data for Tasiilaq found! Appending stats.
# All temperature data for Mount gambier found! Appending stats.
# All temperature data for Port alfred found! Appending stats.
# All temperature data for Hilo found! Appending stats.
# All temperature data for Iglino found! Appending stats.
# All temperature data for Khatanga found! Appending stats.
# All temperature data for Jamestown found! Appending stats.
# All temperature data for Sicuani found! Appending stats.
# All temperature data for Georgetown found! Appending stats.
# All temperature data for Jamestown found! Appending stats.
# All temperature data for Beringovskiy found! Appending stats.
# All temperature data for Jamestown found! Appending stats.
# All temperature data for Pandan found! Appending stats.
# All temperature data for Mamallapuram found! Appending stats.
# All temperature data for Pevek found! Appending stats.
# All temperature data for Mahebourg found! Appending stats.
# All temperature data for Mar del plata found! Appending stats.
# All temperature data for Sinnar found! Appending stats.
# All temperature data for Rawah found! Appending stats.
# Exception type: 'main'
# Temperature data for Tabukiniberu was not found. Skipping this city.
# All temperature data for Birjand found! Appending stats.
# All temperature data for America dourada found! Appending stats.
# All temperature data for Vanimo found! Appending stats.
# All temperature data for Bredasdorp found! Appending stats.
# All temperature data for Vaini found! Appending stats.
# All temperature data for Punta arenas found! Appending stats.
# All temperature data for Wajir found! Appending stats.
#
#
# Accounting for duplicate cities (or errant humidity measurements) within the batch.
#
# All temperature data for Rikitea found! Appending stats.
# All temperature data for Busselton found! Appending stats.
# All temperature data for Carnarvon found! Appending stats.
# All temperature data for Severo-kurilsk found! Appending stats.
# All temperature data for Ushuaia found! Appending stats.
# All temperature data for Kapaa found! Appending stats.
# All temperature data for Kapaa found! Appending stats.
# All temperature data for Hermanus found! Appending stats.
# All temperature data for Bredasdorp found! Appending stats.
# All temperature data for Ushuaia found! Appending stats.
#
#
# Accounting for duplicate cities (or errant humidity measurements) within the batch.
#
# All temperature data for Castro found! Appending stats.
# All temperature data for Mataura found! Appending stats.
# All temperature data for Cherskiy found! Appending stats.
# Exception type: 'main'
# Temperature data for Nizhneyansk was not found. Skipping this city.
# All temperature data for Chapais found! Appending stats.
#
#
# Accounting for duplicate cities (or errant humidity measurements) within the batch.
#
# All temperature data for Punta arenas found! Appending stats.
# All temperature data for Vicam found! Appending stats.
#
#
# Accounting for duplicate cities (or errant humidity measurements) within the batch.
#
# All temperature data for Port alfred found! Appending stats.
#
#
# Accounting for duplicate cities (or errant humidity measurements) within the batch.
#
# All temperature data for Port alfred found! Appending stats.
#
#
# Accounting for duplicate cities (or errant humidity measurements) within the batch.
#
# All temperature data for Hobyo found! Appending stats.
# Success: returning DataFrame of length: 50.
# --------------------------------------------------
#
# Batch 9.
#
# Attempting to retrieve 50 records in this batch.
#
# All temperature data for Olafsvik found! Appending stats.
# All temperature data for Bantry found! Appending stats.
# All temperature data for Tura found! Appending stats.
# All temperature data for Butaritari found! Appending stats.
# All temperature data for Hilo found! Appending stats.
# All temperature data for Carnarvon found! Appending stats.
# All temperature data for Gurupa found! Appending stats.
# All temperature data for Lagoa found! Appending stats.
# All temperature data for Waipawa found! Appending stats.
# All temperature data for Port-gentil found! Appending stats.
# All temperature data for Iqaluit found! Appending stats.
# All temperature data for Hermanus found! Appending stats.
# All temperature data for Rikitea found! Appending stats.
# All temperature data for Dikson found! Appending stats.
# All temperature data for Busselton found! Appending stats.
# All temperature data for Nikolskoye found! Appending stats.
# Exception type: 'main'
# Temperature data for Belushya guba was not found. Skipping this city.
# Exception type: 'main'
# Temperature data for Samusu was not found. Skipping this city.
# All temperature data for Blagoyevo found! Appending stats.
# Exception type: 'main'
# Temperature data for Sorvag was not found. Skipping this city.
# All temperature data for Mackay found! Appending stats.
# All temperature data for Mataura found! Appending stats.
# All temperature data for Bluff found! Appending stats.
# All temperature data for Barrow found! Appending stats.
# All temperature data for Kapaa found! Appending stats.
# All temperature data for Cape town found! Appending stats.
# All temperature data for Akdepe found! Appending stats.
# All temperature data for Orlik found! Appending stats.
# All temperature data for Namatanai found! Appending stats.
# All temperature data for Bluff found! Appending stats.
# Exception type: 'main'
# Temperature data for Marcona was not found. Skipping this city.
# All temperature data for Rikitea found! Appending stats.
# All temperature data for Rikitea found! Appending stats.
# All temperature data for Kavieng found! Appending stats.
# All temperature data for Saint simons found! Appending stats.
# All temperature data for Nikolskoye found! Appending stats.
# All temperature data for Thompson found! Appending stats.
# Exception type: 'main'
# Temperature data for Sentyabrskiy was not found. Skipping this city.
# All temperature data for Lakes entrance found! Appending stats.
# All temperature data for Qaanaaq found! Appending stats.
# All temperature data for Bredasdorp found! Appending stats.
# All temperature data for Arraial do cabo found! Appending stats.
# All temperature data for Arraial do cabo found! Appending stats.
# All temperature data for Odweyne found! Appending stats.
# All temperature data for San patricio found! Appending stats.
# All temperature data for Poya found! Appending stats.
# All temperature data for Tuktoyaktuk found! Appending stats.
# All temperature data for Marzuq found! Appending stats.
# All temperature data for Vaini found! Appending stats.
# All temperature data for Nikolskoye found! Appending stats.
#
#
# Accounting for duplicate cities (or errant humidity measurements) within the batch.
#
# All temperature data for Birzai found! Appending stats.
# All temperature data for Broome found! Appending stats.
# All temperature data for Mehriz found! Appending stats.
# All temperature data for Savannakhet found! Appending stats.
# Exception type: 'main'
# Temperature data for Mys shmidta was not found. Skipping this city.
# All temperature data for Camacha found! Appending stats.
# All temperature data for San rafael del sur found! Appending stats.
# All temperature data for Saint-philippe found! Appending stats.
# All temperature data for Severo-kurilsk found! Appending stats.
# All temperature data for Talnakh found! Appending stats.
# All temperature data for Tuensang found! Appending stats.
#
#
# Accounting for duplicate cities (or errant humidity measurements) within the batch.
#
# All temperature data for Columbus found! Appending stats.
# Success: returning DataFrame of length: 50.
# --------------------------------------------------
#
# Batch 10.
#
# Attempting to retrieve 50 records in this batch.
#
# All temperature data for Erdaojiang found! Appending stats.
# All temperature data for Busselton found! Appending stats.
# All temperature data for Hilo found! Appending stats.
# All temperature data for Carnarvon found! Appending stats.
# All temperature data for Qaanaaq found! Appending stats.
# All temperature data for Ancud found! Appending stats.
# Exception type: 'main'
# Temperature data for Amderma was not found. Skipping this city.
# All temperature data for Teya found! Appending stats.
# All temperature data for Georgetown found! Appending stats.
# Exception type: 'main'
# Temperature data for Badaojiang was not found. Skipping this city.
# All temperature data for Ushuaia found! Appending stats.
# All temperature data for New norfolk found! Appending stats.
# All temperature data for Bluff found! Appending stats.
# All temperature data for Faya found! Appending stats.
# All temperature data for Lata found! Appending stats.
# All temperature data for Qaanaaq found! Appending stats.
# All temperature data for Alofi found! Appending stats.
# All temperature data for Zambezi found! Appending stats.
# All temperature data for Dicabisagan found! Appending stats.
# All temperature data for Bluff found! Appending stats.
# All temperature data for Gouyave found! Appending stats.
# All temperature data for Ushuaia found! Appending stats.
# Exception type: 'main'
# Temperature data for Umzimvubu was not found. Skipping this city.
# All temperature data for Lompoc found! Appending stats.
# All temperature data for Rocha found! Appending stats.
# Exception type: 'main'
# Temperature data for Illoqqortoormiut was not found. Skipping this city.
# All temperature data for Isangel found! Appending stats.
# All temperature data for Fortuna foothills found! Appending stats.
# All temperature data for Alofi found! Appending stats.
# Exception type: 'main'
# Temperature data for Samusu was not found. Skipping this city.
# All temperature data for Hasaki found! Appending stats.
# All temperature data for Shadegan found! Appending stats.
# All temperature data for Mungwi found! Appending stats.
# All temperature data for Chokurdakh found! Appending stats.
# All temperature data for Paamiut found! Appending stats.
# All temperature data for Hermanus found! Appending stats.
# All temperature data for Haines junction found! Appending stats.
# All temperature data for Millinocket found! Appending stats.
# All temperature data for San vicente found! Appending stats.
# All temperature data for Bengkulu found! Appending stats.
# All temperature data for Back mountain found! Appending stats.
# All temperature data for Mataura found! Appending stats.
# All temperature data for Carnarvon found! Appending stats.
# All temperature data for Ucluelet found! Appending stats.
# All temperature data for Banda aceh found! Appending stats.
# All temperature data for Faanui found! Appending stats.
# All temperature data for Port lincoln found! Appending stats.
# All temperature data for Iwanai found! Appending stats.
# All temperature data for Hobart found! Appending stats.
# All temperature data for Klaksvik found! Appending stats.
#
#
# Accounting for duplicate cities (or errant humidity measurements) within the batch.
#
# Exception type: 'main'
# Temperature data for Illoqqortoormiut was not found. Skipping this city.
# All temperature data for Saskylakh found! Appending stats.
# All temperature data for Puerto ayora found! Appending stats.
# All temperature data for New norfolk found! Appending stats.
# All temperature data for Urusha found! Appending stats.
# All temperature data for Bambous virieux found! Appending stats.
# All temperature data for Tuktoyaktuk found! Appending stats.
# All temperature data for Bunawan found! Appending stats.
# Exception type: 'main'
# Temperature data for Belushya guba was not found. Skipping this city.
# All temperature data for Ponta do sol found! Appending stats.
#
#
# Accounting for duplicate cities (or errant humidity measurements) within the batch.
#
# All temperature data for Stanger found! Appending stats.
# All temperature data for Puerto ayora found! Appending stats.
# All temperature data for Hasaki found! Appending stats.
#
#
# Accounting for duplicate cities (or errant humidity measurements) within the batch.
#
# All temperature data for Punta arenas found! Appending stats.
# All temperature data for Albany found! Appending stats.
# Success: returning DataFrame of length: 50.
# --------------------------------------------------
#
#
#
# --------------------------------------------------
# --------------------------------------------------
#
#
# There were some duplicate cities (or errant humidity measurements) when the batches were combined.
# Number of missing records after dropping duplicates: 185.
#
# Attempting to retrieve 185 records in this batch.
#
# All temperature data for Bredasdorp found! Appending stats.
# All temperature data for Port elizabeth found! Appending stats.
# All temperature data for Albany found! Appending stats.
# All temperature data for Bathsheba found! Appending stats.
# All temperature data for Airai found! Appending stats.
# All temperature data for Vetlanda found! Appending stats.
# All temperature data for Souillac found! Appending stats.
# All temperature data for North bend found! Appending stats.
# All temperature data for Severo-kurilsk found! Appending stats.
# All temperature data for Cape town found! Appending stats.
# All temperature data for Hermanus found! Appending stats.
# All temperature data for Vaini found! Appending stats.
# All temperature data for Luderitz found! Appending stats.
# All temperature data for Seymchan found! Appending stats.
# All temperature data for Kapaa found! Appending stats.
# All temperature data for Kendari found! Appending stats.
# All temperature data for Kearney found! Appending stats.
# All temperature data for Lakhipur found! Appending stats.
# All temperature data for Kruisfontein found! Appending stats.
# All temperature data for Bredasdorp found! Appending stats.
# All temperature data for General roca found! Appending stats.
# All temperature data for Shihezi found! Appending stats.
# Exception type: 'main'
# Temperature data for Illoqqortoormiut was not found. Skipping this city.
# Exception type: 'main'
# Temperature data for Sorvag was not found. Skipping this city.
# All temperature data for Punta arenas found! Appending stats.
# All temperature data for Ushuaia found! Appending stats.
# All temperature data for Hilo found! Appending stats.
# All temperature data for Barrow found! Appending stats.
# Exception type: 'main'
# Temperature data for Taolanaro was not found. Skipping this city.
# All temperature data for Hithadhoo found! Appending stats.
# All temperature data for Ilulissat found! Appending stats.
# Exception type: 'main'
# Temperature data for Angra was not found. Skipping this city.
# All temperature data for Lebu found! Appending stats.
# All temperature data for Biltine found! Appending stats.
# All temperature data for Saskylakh found! Appending stats.
# All temperature data for Ilulissat found! Appending stats.
# All temperature data for Cape town found! Appending stats.
# All temperature data for Georgetown found! Appending stats.
# All temperature data for Bethel found! Appending stats.
# All temperature data for Vaini found! Appending stats.
# Exception type: 'main'
# Temperature data for Nizhneyansk was not found. Skipping this city.
# All temperature data for Ilulissat found! Appending stats.
# All temperature data for Kruisfontein found! Appending stats.
# All temperature data for Kapaa found! Appending stats.
# All temperature data for Buttelborn found! Appending stats.
# All temperature data for Sanmenxia found! Appending stats.
# All temperature data for Butaritari found! Appending stats.
# All temperature data for Busselton found! Appending stats.
# All temperature data for Kodiak found! Appending stats.
# All temperature data for Geraldton found! Appending stats.
# All temperature data for Champerico found! Appending stats.
# All temperature data for Esperance found! Appending stats.
# All temperature data for Ushuaia found! Appending stats.
# All temperature data for Goderich found! Appending stats.
# All temperature data for Punta arenas found! Appending stats.
# Exception type: 'main'
# Temperature data for Toliary was not found. Skipping this city.
# All temperature data for Kavieng found! Appending stats.
# All temperature data for Nelson bay found! Appending stats.
# All temperature data for Bonfim found! Appending stats.
# All temperature data for Ushuaia found! Appending stats.
# Exception type: 'main'
# Temperature data for Bolungarvik was not found. Skipping this city.
# All temperature data for Mataura found! Appending stats.
# All temperature data for Half moon bay found! Appending stats.
# Exception type: 'main'
# Temperature data for Imabari was not found. Skipping this city.
# ...
# All temperature data for Svetlyy found! Appending stats.
#
#
# Accounting for duplicate cities (or errant humidity measurements) within the batch.
#
# All temperature data for Barrow found! Appending stats.
# Exception type: 'main'
# Temperature data for Marcona was not found. Skipping this city.
#
#
# Accounting for duplicate cities (or errant humidity measurements) within the batch.
#
# Exception type: 'main'
# Temperature data for Burica was not found. Skipping this city.
# All temperature data for Mar del plata found! Appending stats.
#
#
# Accounting for duplicate cities (or errant humidity measurements) within the batch.
#
# All temperature data for Avarua found! Appending stats.
# All temperature data for Albany found! Appending stats.
#
#
# Accounting for duplicate cities (or errant humidity measurements) within the batch.
#
# All temperature data for Busselton found! Appending stats.
#
#
# Accounting for duplicate cities (or errant humidity measurements) within the batch.
#
# All temperature data for Lebu found! Appending stats.
#
#
# Accounting for duplicate cities (or errant humidity measurements) within the batch.
#
# All temperature data for Tuktoyaktuk found! Appending stats.
# Success: returning DataFrame of length: 81.
#
#
# There were some duplicate cities (or errant humidity measurements) when the batches were combined.
# Number of missing records after dropping duplicates: 47.
#
# Attempting to retrieve 47 records in this batch.
#
# All temperature data for Kirakira found! Appending stats.
# All temperature data for Boa vista found! Appending stats.
# All temperature data for Punta arenas found! Appending stats.
# All temperature data for Mataura found! Appending stats.
# All temperature data for Kavieng found! Appending stats.
# All temperature data for Ushuaia found! Appending stats.
# All temperature data for Viedma found! Appending stats.
# All temperature data for Kavaratti found! Appending stats.
# All temperature data for Grindavik found! Appending stats.
# All temperature data for Hamilton found! Appending stats.
# All temperature data for Barrow found! Appending stats.
# All temperature data for Nome found! Appending stats.
# All temperature data for Mandera found! Appending stats.
# All temperature data for Buena vista found! Appending stats.
# All temperature data for New norfolk found! Appending stats.
# All temperature data for Hermanus found! Appending stats.
# All temperature data for Mataura found! Appending stats.
# All temperature data for Ushuaia found! Appending stats.
# All temperature data for Adrar found! Appending stats.
# All temperature data for Ayan found! Appending stats.
# All temperature data for Rikitea found! Appending stats.
# All temperature data for Clarksville found! Appending stats.
# All temperature data for Cidreira found! Appending stats.
# All temperature data for Punta arenas found! Appending stats.
# All temperature data for Hambantota found! Appending stats.
# All temperature data for Maxixe found! Appending stats.
# All temperature data for Khatanga found! Appending stats.
# All temperature data for Namibe found! Appending stats.
# All temperature data for Thompson found! Appending stats.
# All temperature data for Santa vitoria do palmar found! Appending stats.
# All temperature data for Avarua found! Appending stats.
# All temperature data for Mount gambier found! Appending stats.
# All temperature data for Ribeira grande found! Appending stats.
# All temperature data for Rikitea found! Appending stats.
# All temperature data for Waddan found! Appending stats.
# All temperature data for Yellowknife found! Appending stats.
# All temperature data for Punta arenas found! Appending stats.
# All temperature data for Payo found! Appending stats.
# All temperature data for New norfolk found! Appending stats.
# All temperature data for Hobart found! Appending stats.
# All temperature data for Grindavik found! Appending stats.
# Exception type: 'main'
# Temperature data for Samusu was not found. Skipping this city.
# All temperature data for Martapura found! Appending stats.
# All temperature data for Souillac found! Appending stats.
# All temperature data for Georgetown found! Appending stats.
# Exception type: 'main'
# Temperature data for Tabiauea was not found. Skipping this city.
# All temperature data for Sangmelima found! Appending stats.
#
#
# Accounting for duplicate cities (or errant humidity measurements) within the batch.
#
# All temperature data for Staraya poltavka found! Appending stats.
# All temperature data for Cherskiy found! Appending stats.
# All temperature data for Sao joao do paraiso found! Appending stats.
# All temperature data for Mataura found! Appending stats.
# All temperature data for Baker city found! Appending stats.
# Exception type: 'main'
# Temperature data for Fort saint john was not found. Skipping this city.
# All temperature data for Tasiilaq found! Appending stats.
# All temperature data for Hilo found! Appending stats.
# All temperature data for Butaritari found! Appending stats.
#
#
# Accounting for duplicate cities (or errant humidity measurements) within the batch.
#
# All temperature data for Faya found! Appending stats.
# All temperature data for Rikitea found! Appending stats.
#
#
# Accounting for duplicate cities (or errant humidity measurements) within the batch.
#
# All temperature data for Camacha found! Appending stats.
# Success: returning DataFrame of length: 47.
#
#
# There were some duplicate cities (or errant humidity measurements) when the batches were combined.
# Number of missing records after dropping duplicates: 28.
#
# Attempting to retrieve 28 records in this batch.
#
# Exception type: 'main'
# Temperature data for Marcona was not found. Skipping this city.
# All temperature data for Tautira found! Appending stats.
# All temperature data for Ushuaia found! Appending stats.
# All temperature data for Codrington found! Appending stats.
# All temperature data for Olean found! Appending stats.
# All temperature data for Rikitea found! Appending stats.
# All temperature data for Ushuaia found! Appending stats.
# All temperature data for Kahului found! Appending stats.
# All temperature data for Lodja found! Appending stats.
# All temperature data for Busselton found! Appending stats.
# All temperature data for Arraial do cabo found! Appending stats.
# All temperature data for Shevchenko found! Appending stats.
# All temperature data for Gat found! Appending stats.
# Exception type: 'main'
# Temperature data for Wahran was not found. Skipping this city.
# All temperature data for Kalmar found! Appending stats.
# All temperature data for Ambon found! Appending stats.
# All temperature data for Cape town found! Appending stats.
# All temperature data for Mataura found! Appending stats.
# All temperature data for Port alfred found! Appending stats.
# All temperature data for Cabo san lucas found! Appending stats.
# All temperature data for Voh found! Appending stats.
# All temperature data for Rikitea found! Appending stats.
# All temperature data for Port blair found! Appending stats.
# All temperature data for Bluff found! Appending stats.
# All temperature data for Beringovskiy found! Appending stats.
# All temperature data for Ilulissat found! Appending stats.
# All temperature data for Rikitea found! Appending stats.
# All temperature data for Kenitra found! Appending stats.
#
#
# Accounting for duplicate cities (or errant humidity measurements) within the batch.
#
# All temperature data for Vaini found! Appending stats.
# All temperature data for Husavik found! Appending stats.
# All temperature data for Vaini found! Appending stats.
# All temperature data for Kruisfontein found! Appending stats.
# All temperature data for Tual found! Appending stats.
#
#
# Accounting for duplicate cities (or errant humidity measurements) within the batch.
#
# All temperature data for Ushuaia found! Appending stats.
#
#
# Accounting for duplicate cities (or errant humidity measurements) within the batch.
#
# All temperature data for Mataura found! Appending stats.
#
#
# Accounting for duplicate cities (or errant humidity measurements) within the batch.
#
# All temperature data for Rikitea found! Appending stats.
#
#
# Accounting for duplicate cities (or errant humidity measurements) within the batch.
#
# All temperature data for Pevek found! Appending stats.
# Success: returning DataFrame of length: 28.
#
#
# There were some duplicate cities (or errant humidity measurements) when the batches were combined.
# Number of missing records after dropping duplicates: 20.
#
# Attempting to retrieve 20 records in this batch.
#
# All temperature data for Kokopo found! Appending stats.
# All temperature data for Ushuaia found! Appending stats.
# All temperature data for Yellowknife found! Appending stats.
# All temperature data for Atuona found! Appending stats.
# All temperature data for Suez found! Appending stats.
# All temperature data for Ilulissat found! Appending stats.
# All temperature data for Aksu found! Appending stats.
# All temperature data for Zdvinsk found! Appending stats.
# All temperature data for Albany found! Appending stats.
# All temperature data for Krasnyy chikoy found! Appending stats.
# All temperature data for Tuktoyaktuk found! Appending stats.
# All temperature data for Wajir found! Appending stats.
# All temperature data for Ada found! Appending stats.
# All temperature data for Vaini found! Appending stats.
# All temperature data for Jamestown found! Appending stats.
# All temperature data for Barrow found! Appending stats.
# All temperature data for Saint-philippe found! Appending stats.
# All temperature data for Versalles found! Appending stats.
# All temperature data for Kruisfontein found! Appending stats.
# All temperature data for Bethel found! Appending stats.
# Success: returning DataFrame of length: 20.
#
#
# There were some duplicate cities (or errant humidity measurements) when the batches were combined.
# Number of missing records after dropping duplicates: 13.
#
# Attempting to retrieve 13 records in this batch.
#
# All temperature data for Puerto ayora found! Appending stats.
# All temperature data for Mataura found! Appending stats.
# All temperature data for Tshikapa found! Appending stats.
# All temperature data for Sterling found! Appending stats.
# All temperature data for Lenger found! Appending stats.
# All temperature data for Barrow found! Appending stats.
# All temperature data for Cabo san lucas found! Appending stats.
# All temperature data for Vaini found! Appending stats.
# All temperature data for Rikitea found! Appending stats.
# All temperature data for Sao filipe found! Appending stats.
# All temperature data for Luangwa found! Appending stats.
# All temperature data for Avarua found! Appending stats.
# All temperature data for Punta arenas found! Appending stats.
# Success: returning DataFrame of length: 13.
#
#
# There were some duplicate cities (or errant humidity measurements) when the batches were combined.
# Number of missing records after dropping duplicates: 8.
#
# Attempting to retrieve 8 records in this batch.
#
# All temperature data for Ilulissat found! Appending stats.
# All temperature data for Yulara found! Appending stats.
# All temperature data for Hilo found! Appending stats.
# All temperature data for Uyuni found! Appending stats.
# All temperature data for Hithadhoo found! Appending stats.
# All temperature data for Cape canaveral found! Appending stats.
# All temperature data for Basco found! Appending stats.
# All temperature data for Puerto ayora found! Appending stats.
# Success: returning DataFrame of length: 8.
#
#
# There were some duplicate cities (or errant humidity measurements) when the batches were combined.
# Number of missing records after dropping duplicates: 4.
#
# Attempting to retrieve 4 records in this batch.
#
# All temperature data for Banda aceh found! Appending stats.
# All temperature data for Albany found! Appending stats.
# All temperature data for Mount gambier found! Appending stats.
# All temperature data for Ulaanbaatar found! Appending stats.
# Success: returning DataFrame of length: 4.
#
#
# There were some duplicate cities (or errant humidity measurements) when the batches were combined.
# Number of missing records after dropping duplicates: 3.
#
# Attempting to retrieve 3 records in this batch.
#
# All temperature data for Lebu found! Appending stats.
# All temperature data for Pevek found! Appending stats.
# All temperature data for Bredasdorp found! Appending stats.
# Success: returning DataFrame of length: 3.
#
#
# There were some duplicate cities (or errant humidity measurements) when the batches were combined.
# Number of missing records after dropping duplicates: 3.
#
# Attempting to retrieve 3 records in this batch.
#
# All temperature data for Ushuaia found! Appending stats.
# All temperature data for Cape town found! Appending stats.
# All temperature data for Isangel found! Appending stats.
# Success: returning DataFrame of length: 3.
#
#
# There were some duplicate cities (or errant humidity measurements) when the batches were combined.
# Number of missing records after dropping duplicates: 3.
#
# Attempting to retrieve 3 records in this batch.
#
# All temperature data for Mataura found! Appending stats.
# All temperature data for Fushan found! Appending stats.
# All temperature data for Punta arenas found! Appending stats.
# Success: returning DataFrame of length: 3.
#
#
# There were some duplicate cities (or errant humidity measurements) when the batches were combined.
# Number of missing records after dropping duplicates: 2.
#
# Attempting to retrieve 2 records in this batch.
#
# Exception type: 'main'
# Temperature data for Nguiu was not found. Skipping this city.
# All temperature data for Tiksi found! Appending stats.
#
#
# Accounting for duplicate cities (or errant humidity measurements) within the batch.
#
# All temperature data for Cidreira found! Appending stats.
# Success: returning DataFrame of length: 2.
#
#
# There were some duplicate cities (or errant humidity measurements) when the batches were combined.
# Number of missing records after dropping duplicates: 2.
#
# Attempting to retrieve 2 records in this batch.
#
# Exception type: 'main'
# Temperature data for Yeletskiy was not found. Skipping this city.
# All temperature data for Ushuaia found! Appending stats.
#
#
# Accounting for duplicate cities (or errant humidity measurements) within the batch.
#
# All temperature data for Pevek found! Appending stats.
# Success: returning DataFrame of length: 2.
#
#
# There were some duplicate cities (or errant humidity measurements) when the batches were combined.
# Number of missing records after dropping duplicates: 2.
#
# Attempting to retrieve 2 records in this batch.
#
# All temperature data for Saint-philippe found! Appending stats.
# All temperature data for Kirkenaer found! Appending stats.
# Success: returning DataFrame of length: 2.
#
#
# There were some duplicate cities (or errant humidity measurements) when the batches were combined.
# Number of missing records after dropping duplicates: 1.
#
# Attempting to retrieve 1 records in this batch.
#
# All temperature data for Beloha found! Appending stats.
# Success: returning DataFrame of length: 1.
#
#
# There were some duplicate cities (or errant humidity measurements) when the batches were combined.
# Number of missing records after dropping duplicates: 1.
#
# Attempting to retrieve 1 records in this batch.
#
# All temperature data for Rikitea found! Appending stats.
# Success: returning DataFrame of length: 1.
#
#
# There were some duplicate cities (or errant humidity measurements) when the batches were combined.
# Number of missing records after dropping duplicates: 1.
#
# Attempting to retrieve 1 records in this batch.
#
# Exception type: 'main'
# Temperature data for Belushya guba was not found. Skipping this city.
#
#
# Accounting for duplicate cities (or errant humidity measurements) within the batch.
#
# All temperature data for Ushuaia found! Appending stats.
# Success: returning DataFrame of length: 1.
#
#
# There were some duplicate cities (or errant humidity measurements) when the batches were combined.
# Number of missing records after dropping duplicates: 1.
#
# Attempting to retrieve 1 records in this batch.
#
# All temperature data for Sao miguel do araguaia found! Appending stats.
# Success: returning DataFrame of length: 1.
#
#
# Weather data for a total of 500 cities have been retrieved.
# Your query is complete!

# %%
display(weather_batch_all)
# Out:
#                        city  latitude  longitude  max_temp  humidity  \
# 0             Mar del plata    -38.17     -57.42     64.40      68.0
# 1                   Rikitea    -86.82    -128.74     77.72      75.0
# 2                      Fare    -12.96    -148.54     80.94      64.0
# 3                  Saldanha    -37.33      10.55     60.80      88.0
# 4             San policarpo     16.19     132.14     78.46      77.0
# ..                      ...       ...        ...       ...       ...
# 495                   Basco     20.52     125.74     75.94      76.0
# 496             Ulaanbaatar     47.90     108.34     32.00      80.0
# 497                  Fushan     37.41     121.19     52.27      59.0
# 498               Kirkenaer     60.49      12.46     42.80      42.0
# 499  Sao miguel do araguaia    -12.73     -50.42     89.35      46.0
#
#      cloud_cover  wind_speed country          date
# 0           75.0       16.11      AR  1.619372e+09
# 1           85.0        6.69      PF  1.619372e+09
# 2           24.0        4.72      PF  1.619372e+09
# 3           99.0        4.61      ZA  1.619372e+09
# 4           93.0        9.69      PH  1.619372e+09
# ..           ...         ...     ...           ...
# 495         97.0       18.97      PH  1.619373e+09
# 496         75.0        8.95      MN  1.619373e+09
# 497        100.0        1.57      CN  1.619373e+09
# 498         89.0       14.97      NO  1.619373e+09
# 499         54.0        1.41      BR  1.619373e+09
#
# [500 rows x 9 columns]

# %%
# Convert Unix time-stamp to data and hour
weather_batch_all['date'] = pd.to_datetime(weather_batch_all['date'], unit='s')

weather_batch_all.head(50)
# Out:
#                      city  latitude  longitude  max_temp  humidity  \
# 0           Mar del plata    -38.17     -57.42     64.40      68.0
# 1                 Rikitea    -86.82    -128.74     77.72      75.0
# 2                    Fare    -12.96    -148.54     80.94      64.0
# 3                Saldanha    -37.33      10.55     60.80      88.0
# 4           San policarpo     16.19     132.14     78.46      77.0
# 5            Port hueneme     32.72    -119.95     63.00      67.0
# 6                  Sorong     -0.09     129.87     78.01      88.0
# 7            Port lincoln    -43.73     132.51     59.38      78.0
# 8              Butaritari     13.29     170.14     82.22      77.0
# 9              Nikolskoye     30.99     177.30     39.99      87.0
# 10               Belmonte    -18.10     -28.50     84.20      65.0
# 11           Punta arenas    -86.42     -98.06     59.00      47.0
# 12               Cidreira    -55.80     -25.24     70.75      72.0
# 13               Zhigansk     67.49     125.81     32.49      98.0
# 14     Comodoro rivadavia    -50.16     -62.91     64.40      45.0
# 15                 Atuona      0.95    -131.31     79.95      70.0
# 16                Qaanaaq     89.80     -66.00     31.57      74.0
# 17               Lang son     22.16     107.40     73.69      94.0
# 18                   Lebu    -31.07     -89.30     60.26      74.0
# 19             Kaitangata    -51.21     171.26     36.00      76.0
# 20                Mildura    -33.30     143.68     50.00      81.0
# 21                 Albany    -83.41     115.24     55.00      62.0
# 22               Calabozo      7.60     -66.67     98.73      27.0
# 23                   Hilo     26.72    -147.16     68.00      83.0
# 24          Alice springs    -25.30     137.35     48.20      61.0
# 25         Severo-kurilsk     44.81     155.46     31.57      97.0
# 26                 Jibuti     12.27      42.78     86.00      74.0
# 27               Tasiilaq     75.34     -38.82     39.20      65.0
# 28                  Tiksi     86.88     125.32     20.48      96.0
# 29  Conceicao do araguaia     -7.87     -49.63     80.60      74.0
# 30            Eckernforde     54.52       9.73     50.00      34.0
# 31              Churapcha     62.84     133.12     27.30      98.0
# 32             Nanortalik     57.54     -44.72     42.69      73.0
# 33              Cape town    -51.23       6.05     66.00      88.0
# 34            Tuktoyaktuk     81.66    -127.09     10.40      85.0
# 35                    Mao     15.88      16.34     62.60      72.0
# 36                  Tabuk     29.07      35.93     69.98      88.0
# 37                 Tucson     32.13    -110.77     84.99      12.0
# 38            Yellowknife     68.09    -113.97      6.80      56.0
# 39              Mahebourg    -55.64      79.55     77.00      88.0
# 40               Cherskiy     87.71     161.31      0.34      97.0
# 41                Samarai    -12.55     149.99     82.98      77.0
# 42            Bronnoysund     66.24      11.33     39.20      65.0
# 43              Hithadhoo    -15.94      73.66     83.07      67.0
# 44                  Mutsu     41.04     141.17     42.01      60.0
# 45                Huarmey    -13.91     -87.81     72.91      73.0
# 46                Ushuaia    -81.50     -36.74     55.40      50.0
# 47            Nortelandia    -12.86     -56.90     78.69      84.0
# 48               Ibicarai    -14.88     -39.61     86.00      70.0
# 49                  Bowen    -16.78     150.26     71.60      83.0
#
#     cloud_cover  wind_speed country                date
# 0          75.0       16.11      AR 2021-04-25 17:41:04
# 1          85.0        6.69      PF 2021-04-25 17:39:48
# 2          24.0        4.72      PF 2021-04-25 17:41:04
# 3          99.0        4.61      ZA 2021-04-25 17:32:09
# 4          93.0        9.69      PH 2021-04-25 17:41:05
# 5          40.0        3.44      US 2021-04-25 17:41:05
# 6          70.0       11.32      ID 2021-04-25 17:41:06
# 7          44.0        7.99      AU 2021-04-25 17:41:06
# 8          27.0       10.60      KI 2021-04-25 17:27:49
# 9          75.0       11.18      RU 2021-04-25 17:31:37
# 10         40.0       14.97      BR 2021-04-25 17:33:26
# 11         75.0       23.02      CL 2021-04-25 17:38:55
# 12         87.0       15.61      BR 2021-04-25 17:30:16
# 13        100.0       10.45      RU 2021-04-25 17:41:07
# 14          0.0       14.97      AR 2021-04-25 17:41:07
# 15         61.0       17.00      PF 2021-04-25 17:41:08
# 16         87.0        2.89      GL 2021-04-25 17:41:08
# 17        100.0        3.53      VN 2021-04-25 17:37:52
# 18          0.0       13.18      CL 2021-04-25 17:31:12
# 19         43.0        1.99      NZ 2021-04-25 17:41:08
# 20          7.0        2.30      AU 2021-04-25 17:31:43
# 21        100.0        2.86      US 2021-04-25 17:37:38
# 22         52.0        9.04      VE 2021-04-25 17:36:55
# 23         90.0        3.44      US 2021-04-25 17:36:25
# 24          0.0        1.14      AU 2021-04-25 17:38:57
# 25        100.0        9.75      RU 2021-04-25 17:29:19
# 26         75.0       15.82      DJ 2021-04-25 17:41:10
# 27         75.0       23.02      GL 2021-04-25 17:41:10
# 28         99.0        3.78      RU 2021-04-25 17:41:10
# 29          0.0        8.05      BR 2021-04-25 17:41:11
# 30         50.0       17.27      DE 2021-04-25 17:41:11
# 31        100.0        2.33      RU 2021-04-25 17:41:12
# 32        100.0       13.15      GL 2021-04-25 17:33:02
# 33          0.0       17.27      ZA 2021-04-25 17:36:17
# 34         90.0       10.36      CA 2021-04-25 17:41:12
# 35          0.0       17.27      ES 2021-04-25 17:41:13
# 36         22.0        3.56      PH 2021-04-25 17:41:13
# 37          1.0        8.05      US 2021-04-25 17:39:49
# 38         75.0        5.75      CA 2021-04-25 17:39:52
# 39         75.0       12.66      MU 2021-04-25 17:37:25
# 40         99.0        4.47      RU 2021-04-25 17:41:14
# 41         88.0       12.91      PG 2021-04-25 17:41:14
# 42         40.0       18.41      NO 2021-04-25 17:41:15
# 43         49.0        3.71      MV 2021-04-25 17:41:15
# 44         17.0        3.00      JP 2021-04-25 17:41:15
# 45         28.0       10.20      PE 2021-04-25 17:31:23
# 46         75.0       18.41      AR 2021-04-25 17:39:03
# 47         99.0        5.66      BR 2021-04-25 17:41:16
# 48         20.0        6.91      BR 2021-04-25 17:41:16
# 49         90.0        8.05      AU 2021-04-25 17:31:20

# %%
# Save file to .csv
weather_batch_all.to_csv("output_data\city_weather.csv", index = True, header = True)

# %%
# To read .csv back in...
weather_batch_all = pd.read_csv("output_data\city_weather.csv", index_col = 0)

# %%
max_temp_plot = weather_batch_all.plot("latitude", "max_temp", 
                                       kind = "scatter", 
                                       color = "orange")

max_temp_plot.set_xlabel("Latitude")
max_temp_plot.set_ylabel("Maximum Temperature (F)")
plt.title("Maximum Temperature (F) vs. Latitude")
plt.savefig("Images/maxtemp_all.png")
plt.show()

# %% [markdown]
# This scatter plot shows the relationship between maximum temperature and latitude.
#
# * Note that the relationship is nonlinear because temperature increases when moving from the poles to the Equator.

# %%
humidity_plot = weather_batch_all.plot("latitude", "humidity", 
                                       kind = "scatter", 
                                       color = "orange")

humidity_plot.set_xlabel("Latitude")
humidity_plot.set_ylabel("% Humidity")
plt.title("Percent Humidity vs. Latitude")
plt.savefig("Images/humidity_all.png")
plt.show()

# %% [markdown]
# This scatter plot shows the relationship between latitude and percent humidity.
#
#    * There is not a clear linear relationship between these variables.
#    * Variance in humidity changes with latitude.

# %%
cloud_cover_plot = weather_batch_all.plot("latitude", "cloud_cover", 
                                          kind = "scatter", 
                                          color = "orange")

cloud_cover_plot.set_xlabel("Latitude")
cloud_cover_plot.set_ylabel("% Cloud Cover")
plt.title("Percent Cloud Cover vs. Latitude")
plt.savefig("Images/cloudcover_all.png")
plt.show()

# %% [markdown]
# This scatter plot shows the relationship between latitude and percent cloud cover.
#
#    * There distribution here is multimodal, with bias towards 0 and 100% cloud cover.
#    * There does not appear to be a clear linear relationship between these variables.

# %%
wind_speed_plot = weather_batch_all.plot("latitude", "wind_speed", 
                                         kind = "scatter", 
                                         color = "orange")

wind_speed_plot.set_xlabel("Latitude")
wind_speed_plot.set_ylabel("Wind Speed (mph)")
plt.title("Wind Speed vs. Latitude")
plt.savefig("Images/windspeed_all.png")
plt.show()

# %% [markdown]
# This scatter plot shows the relationship between latitude and wind speed.
#
#    * The highest recorded wind speeds do appear to be in the northern hemisphere.
#    * However there is substantial variance in wind speed at all latitudes.

# %%
northern_hem = weather_batch_all.loc[weather_batch_all["latitude"] > 0]
southern_hem = weather_batch_all.loc[weather_batch_all["latitude"] < 0]

# %%
# max_temp: northern hemisphere

x_values = northern_hem["latitude"]
y_values = northern_hem["max_temp"]


(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = (x_values * slope) + intercept
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

plt.scatter(x_values, y_values, color = "orange")
plt.plot(x_values, regress_values, color = "red")
plt.xlabel("Latitude")
plt.ylabel("Maximum Temperature (F)")
plt.title("Maximum Temperature (F) vs. Latitude: Northern Hemisphere", fontsize = 10)
plt.annotate(line_eq, (50, 85), fontsize = 15, color = "red")

plt.savefig("Images/maxtemp_north.png")
plt.show()

R2 = rvalue**2
regression_table = pd.DataFrame({"Coefficient":[slope], 
                                 "Std_Error":[stderr], 
                                 "P_value":[pvalue], 
                                 "R_squared":[R2]}, index = ["max_temp"])

display(regression_table)
# Out:
#           Coefficient  Std_Error       P_value  R_squared
# max_temp    -0.869022   0.033056  2.458115e-83   0.674186

# %% [markdown]
# This scatter plot shows the relationship between latitude and maximum temperature in the Northern Hemisphere.
#
# A linear regression model (with fit line) have been superimposed on the scatter plot.
#
#    * The linear regression indicates a significant decrease in average temperature with a one-degree increase in latitude.
#        * Overall, a moderate to high proportion of the variance in temperature is explained by latitude (~ 73%).
#
#    * The regression residuals may be correlated.
#        * Observed temperatures were consistently higher than predicted near the equator and lower at intermediate
#          latitudes.
#        * However, the null hypothesis that residuals are normally distributed could not be rejected at alpha = 5%.

# %%
# Pull out the residuals and plot them

# From above
x_values = northern_hem["latitude"]
y_values = northern_hem["max_temp"]
regress_values = (x_values * slope) + intercept

res_max_temp_NH = y_values - regress_values

plt.scatter(x_values, res_max_temp_NH)
plt.hlines(0, xmin = 0, xmax = max(x_values))
plt.title("Residuals from regression of max_temp on latitude (Northern Hemisphere)", fontsize = 10)
plt.show()

st.normaltest(res_max_temp_NH)
# Out:
# NormaltestResult(statistic=4.893312418055786, pvalue=0.08658261717463635)

# %% [markdown]
# Reject null hypothesis that residuals are normally distributed!

# %%
# max_temp: southern hemisphere

x_values = southern_hem["latitude"]
y_values = southern_hem["max_temp"]


(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = (x_values * slope) + intercept
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

plt.scatter(x_values, y_values, color = "orange")
plt.plot(x_values, regress_values, color = "red")
plt.xlabel("Latitude")
plt.ylabel("Maximum Temperature (F)")
plt.title("Maximum Temperature (F) vs. Latitude: Southern Hemisphere", fontsize = 10)
plt.annotate(line_eq, (-75, 87), fontsize = 15, color = "red")

plt.savefig("Images/maxtemp_south.png")
plt.show()

R2 = rvalue**2
regression_table = pd.DataFrame({"Coefficient":[slope], 
                                 "Std_Error":[stderr], 
                                 "P_value":[pvalue],
                                 "R_squared":[R2]}, index = ["max_temp"])

display(regression_table)
# Out:
#           Coefficient  Std_Error       P_value  R_squared
# max_temp     0.308236   0.040833  3.015202e-12   0.260212

# %% [markdown]
# This scatter plot shows the relationship between latitude and maximum temperature in the Southern Hemisphere.
#
# A linear regression model (with fit line) have been superimposed on the scatter plot.
#
#    * The linear regression indicates a significant increase in average temperature with a one-degree increase in latitude.
#        * Overall, 33% of the variance in temperature is explained by latitude.
#            * This is substantially less than what was observed in the Northern Hemisphere.
#
#    * The residuals appear to be correlated and the variance is heteroskedastic (i.e., not constant).
#        * Variance in observed temperatures was highest near the South Pole and low nearer the Equator.
#        * Temperatures were consistently lower than predicted at intermediate latitudes.
#        * However, the null hypothesis that the residuals are normally distributed could not be rejected at alpha = 5%.
#        * For these reasons, simple (OLS) regression may be inappropriate for these data.

# %%
# Pull out the residuals and plot them

# From above
x_values = southern_hem["latitude"]
y_values = southern_hem["max_temp"]
regress_values = (x_values * slope) + intercept

res_max_temp_SH = y_values - regress_values

plt.scatter(x_values, res_max_temp_SH)
plt.hlines(0, xmin = -90, xmax = max(x_values))
plt.title("Residuals from regression of max_temp on latitude (Southern Hemisphere)", fontsize = 10)
plt.show()

st.normaltest(res_max_temp_SH)
# Out:
# NormaltestResult(statistic=5.835151457427942, pvalue=0.05406459580457844)

# %% [markdown]
# Reject null hypothesis that residuals are normally distributed.

# %%
# humidity: northern hemisphere

x_values = northern_hem["latitude"]
y_values = northern_hem["humidity"]


(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = (x_values * slope) + intercept
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

plt.scatter(x_values, y_values, color = "orange")
plt.plot(x_values, regress_values, color = "red")
plt.xlabel("Latitude")
plt.ylabel("% Humidity")
plt.title("% Humidity vs. Latitude: Northern Hemisphere", fontsize = 10)
plt.annotate(line_eq, (50, 8), fontsize = 15, color = "red")

plt.savefig("Images/humdity_north.png")
plt.show()

R2 = rvalue**2
regression_table = pd.DataFrame({"Coefficient":[slope], 
                                 "Std_Error":[stderr], 
                                 "P_value":[pvalue],
                                 "R_squared":[R2]}, index = ["humidity"])

display(regression_table)
# Out:
#           Coefficient  Std_Error   P_value  R_squared
# humidity     0.273525    0.05928  0.000006   0.059923

# %% [markdown]
# This scatter plot shows the relationship between latitude and percent humidity in the Northern Hemisphere.
#
# A linear regression model (with fit line) have been superimposed on the scatter plot.
#
#    * Only 0.5% of the variance in percent humidity is explained by latitude in the Northern Hemisphere.
#    * Nevertheless:
#        * Many of the observed data points are concentrated at high humidities, especially near the North Pole and Equator.
#            * Model residuals appear to be correlated and left skewed.
#        * The residuals are not normally distributed (see cell, below).
#        * Percentage is also an inappropriate response variable for an OLS regression.
#            * The preferred method is called "Beta Regression."
#        * For these reasons, simple OLS regression is inappropriate for these data.

# %%
# Pull out the residuals and plot them

# From above
x_values = northern_hem["latitude"]
y_values = northern_hem["humidity"]
regress_values = (x_values * slope) + intercept

res_humidity_NH = y_values - regress_values

plt.scatter(x_values, res_humidity_NH)
plt.hlines(0, xmin = 0, xmax = max(x_values))
plt.title("Residuals from regression of % humidity on latitude (Northern Hemisphere)", fontsize = 10)
plt.show()

st.normaltest(res_humidity_NH)
# Out:
# NormaltestResult(statistic=40.039420214907096, pvalue=2.0209258126169365e-09)

# %% [markdown]
# Reject null hypothesis that residuals are normally distributed.

# %%
# humidity: southern hemisphere

x_values = southern_hem["latitude"]
y_values = southern_hem["humidity"]


(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = (x_values * slope) + intercept
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

plt.scatter(x_values, y_values, color = "orange")
plt.plot(x_values, regress_values, color = "red")
plt.xlabel("Latitude")
plt.ylabel("% Humidity")
plt.title("% Humidity vs. Latitude: Southern Hemisphere", fontsize = 10)
plt.annotate(line_eq, (-85, 20), fontsize = 15, color = "red")

plt.savefig("Images/humdity_south.png")
plt.show()

R2 = rvalue**2
regression_table = pd.DataFrame({"Coefficient":[slope], 
                                 "Std_Error":[stderr], 
                                 "P_value":[pvalue],
                                 "R_squared":[R2]}, index = ["humidity"])

display(regression_table)
# Out:
#           Coefficient  Std_Error   P_value  R_squared
# humidity     0.048542   0.076731  0.527865   0.002464

# %% [markdown]
# This scatter plot shows the relationship between latitude and percent humidity in the Southern Hemisphere.
#
# A linear regression model (with fit line) have been superimposed on the scatter plot.
#
#    * Only 0.6% of the variance in percent humidity is explained by latitude in the Northern Hemisphere.
#    * Nevertheless:
#        * Many of the observed data points are concentrated at high humidities, especially near the Equator.
#            * Compared to the Northern Hemisphere, where humidity was highest both near the Equator and North Pole.
#        * The variance is heteroskedastic; varicne is generally lower near the equator.
#        * The residuals are not normally distributed (see cell, below).
#        * Percentage is an inappropriate response variable for a simple regression model.
#            * The preferred method is called "Beta Regression."
#        * For these reasons, simple (OLS) regression is likely inapproriate for these data.

# %%
# Pull out the residuals and plot them

# From above
x_values = southern_hem["latitude"]
y_values = southern_hem["humidity"]
regress_values = (x_values * slope) + intercept

res_humidity_SH = y_values - regress_values

plt.scatter(x_values, res_humidity_SH)
plt.hlines(0, xmin = -90, xmax = max(x_values))
plt.title("Residuals from regression of % humidity on latitude (Southern Hemisphere)", fontsize = 10)
plt.show()

st.normaltest(res_humidity_SH)
# Out:
# NormaltestResult(statistic=23.478246201151272, pvalue=7.975604597440483e-06)

# %% [markdown]
# Reject the null hypothesis that the residuals are normally distributed.

# %%
# cloud_cover: northern hemisphere

x_values = northern_hem["latitude"]
y_values = northern_hem["cloud_cover"]


(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = (x_values * slope) + intercept
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

plt.scatter(x_values, y_values, color = "orange")
plt.plot(x_values, regress_values, color = "red")
plt.xlabel("Latitude")
plt.ylabel("% Cloud Cover")
plt.title("% Cloud Cover vs. Latitude: Northern Hemisphere", fontsize = 10)
plt.annotate(line_eq, (56, 55), fontsize = 15, color = "red")

plt.savefig("Images/cloudcover_north.png")
plt.show()

R2 = rvalue**2
regression_table = pd.DataFrame({"Coefficient":[slope], 
                                 "Std_Error":[stderr], 
                                 "P_value":[pvalue],
                                 "R_value":[R2]}, index = ["cloud_cover"])

display(regression_table)
# Out:
#              Coefficient  Std_Error  P_value   R_value
# cloud_cover     0.218704   0.089313  0.01485  0.017636

# %% [markdown]
# This scatter plot shows the relationship between latitude and percent cloud cover in the Southern Hemisphere.
#
# A linear regression model (with fit line) have been superimposed on the scatter plot.
#
#    * Only 0.4% of the variance in percent cloud cover is explained by latitude.
#    * Values tend to be concentrated at 0 (sunny) and 100% (cloudy).
#    * The residuals are not normally distributed (see cell, below).
#    * Percentage is an inappropriate response for an OLS regression.
#        * The preferred method is called "Beta Regression."
#    * For these reasons, simple (OLS) regression may be inappropriate for these data.

# %%
# Pull out the residuals and plot them

# From above
x_values = northern_hem["latitude"]
y_values = northern_hem["cloud_cover"]
regress_values = (x_values * slope) + intercept

res_cloudcover_NH = y_values - regress_values

plt.scatter(x_values, res_cloudcover_NH)
plt.hlines(0, xmin = 0, xmax = max(x_values))
plt.title("Residuals from regression of % cloud cover on latitude (Northern Hemisphere)", fontsize = 10)
plt.show()

st.normaltest(res_cloudcover_NH)
# Out:
# NormaltestResult(statistic=645.7072785304166, pvalue=6.115697625617631e-141)

# %% [markdown]
# Reject the null hypothesis that the residuals are normally distributed.

# %%
# cloud_cover: southern hemisphere

x_values = southern_hem["latitude"]
y_values = southern_hem["cloud_cover"]


(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = (x_values * slope) + intercept
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

plt.scatter(x_values, y_values, color = "orange")
plt.plot(x_values, regress_values, color = "red")
plt.xlabel("Latitude")
plt.ylabel("% Cloud Cover")
plt.title("% Humidity vs. Latitude: Southern Hemisphere", fontsize = 10)
plt.annotate(line_eq, (-88, 62), fontsize = 15, color = "red")

plt.savefig("Images/cloudcover_south.png")
plt.show()

R2 = rvalue**2
regression_table = pd.DataFrame({"Coefficient":[slope], 
                                 "Std_Error":[stderr], 
                                 "P_value":[pvalue],
                                 "R_value":[R2]}, index = ["cloud_cover"])

display(regression_table)
# Out:
#              Coefficient  Std_Error   P_value   R_value
# cloud_cover    -0.081669   0.151563  0.590734  0.001789

# %% [markdown]
# This scatter plot shows the relationship between latitude and percent cloud cover in the Southern Hemisphere.
#
# A linear regression model (with fit line) have been superimposed on the scatter plot.
#
#    * Only 0.02% of the variance in percent cloud cover is explained by latitude.
#    * Values tend to be concentrated at 0 (sunny) and 100% (cloudy).
#        * This plot also clearly shows the lower sample size at the lowest latitudes in the Southern Hemisphere.
#    * The residuals are not normally distributed (see cell, below).
#    * Percentage is an inappropriate response for an OLS regression.
#        * The preferred method is called "Beta Regression."
#    * For these reasons, simple (OLS) regression may be inappropriate for these data.

# %%
# Pull out the residuals and plot them

# From above
x_values = southern_hem["latitude"]
y_values = southern_hem["cloud_cover"]
regress_values = (x_values * slope) + intercept

res_cloudcover_SH = y_values - regress_values

plt.scatter(x_values, res_cloudcover_SH)
plt.hlines(0, xmin = -90, xmax = max(x_values))
plt.title("Residuals from regression of % cloud cover on latitude (Southern Hemisphere)", fontsize = 10)
plt.show()

st.normaltest(res_cloudcover_SH)
# Out:
# NormaltestResult(statistic=4049.0203361322333, pvalue=0.0)

# %%
# wind speed: northern hemisphere

x_values = northern_hem["latitude"]
y_values = northern_hem["wind_speed"]


(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = (x_values * slope) + intercept
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

plt.scatter(x_values, y_values, color = "orange")
plt.plot(x_values, regress_values, color = "red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("Wind Speed (mph) vs. Latitude: Northern Hemisphere", fontsize = 10)
plt.annotate(line_eq, (50, 30), fontsize = 15, color = "red")

plt.savefig("Images/windspeed_north.png")
plt.show()

R2 = rvalue**2
regression_table = pd.DataFrame({"Coefficient":[slope], 
                                 "Std_Error":[stderr], 
                                 "P_value":[pvalue],
                                 "R_squared":[R2]}, index = ["wind_speed"])

display(regression_table)
# Out:
#             Coefficient  Std_Error   P_value  R_squared
# wind_speed      0.00749   0.013456  0.578157   0.000927

# %% [markdown]
# This scatter plot shows the relationship between latitude and wind speed in the Northern Hemisphere.
#
# A linear regression model (with fit line) have been superimposed on the scatter plot.
#
#    * Only 0.3% of the variance in percent wind speed is explained by latitude.
#    * Wind speeds were consistently lower than expected across most latitudes.
#        * The highest wind speeds were found at intermediate latitudes.
#        * Variance in temperature is right skewed.
#        * The residuals are not normally distributed (see cell, below).
#        * For these reasons, simple (OLS) regression may be inappropriate for these data.

# %%
# Pull out the residuals and plot them

# From above
x_values = northern_hem["latitude"]
y_values = northern_hem["wind_speed"]
regress_values = (x_values * slope) + intercept

res_windspeed_NH = y_values - regress_values

plt.scatter(x_values, res_windspeed_NH)
plt.hlines(0, xmin = 0, xmax = max(x_values))
plt.title("Residuals from regression of wind speed (mph) on latitude (Northern Hemisphere)", fontsize = 10)
plt.show()

st.normaltest(res_windspeed_NH)
# Out:
# NormaltestResult(statistic=65.32889886134171, pvalue=6.516431852436229e-15)

# %%
# wind speed: southern hemisphere

x_values = southern_hem["latitude"]
y_values = southern_hem["wind_speed"]


(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = (x_values * slope) + intercept
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

plt.scatter(x_values, y_values, color = "orange")
plt.plot(x_values, regress_values, color = "red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("Wind Speed (mph) vs. Latitude: Southern Hemisphere", fontsize = 10)
plt.annotate(line_eq, (-80, 18), fontsize = 15, color = "red")

plt.savefig("Images/windspeed_south.png")
plt.show()

R2 = rvalue**2
regression_table = pd.DataFrame({"Coefficient":[slope], 
                                 "Std_Error":[stderr], 
                                 "P_value":[pvalue],
                                 "R_squared":[R2]}, index = ["wind_speed"])

display(regression_table)
# Out:
#             Coefficient  Std_Error   P_value  R_squared
# wind_speed    -0.062884   0.019194  0.001287   0.062143

# %% [markdown]
# This scatter plot shows the relationship between latitude and wind speed in the Southern Hemisphere.
#
# A linear regression model (with fit line) have been superimposed on the scatter plot.
#
#    * 4.4% of the variance in percent wind speed was explained by latitude, which is low, but higher than in the Northern
#      Hemisphere.
#    * Interestingly, the overall pattern appears slightly different than in the Northern Latitude.
#        * This could partly be due to lower sample size.
#    * Variance in wind speed appears to decrease as you approach the Equator.
#    * The residuals are not normally distributed (see cell, below).
#    * For these reasons, simple (OLS) regression may be inappropriate for these data.

# %%
# Pull out the residuals and plot them

# From above
x_values = southern_hem["latitude"]
y_values = southern_hem["wind_speed"]
regress_values = (x_values * slope) + intercept

res_windspeed_SH = y_values - regress_values

plt.scatter(x_values, res_windspeed_SH)
plt.hlines(0, xmin = -90, xmax = max(x_values))
plt.title("Residuals from regression of wind speed (mph) on latitude (Southern Hemisphere)", fontsize = 10)
plt.show()

st.normaltest(res_windspeed_SH)
# Out:
# NormaltestResult(statistic=11.769711712633594, pvalue=0.0027812470956337194)
